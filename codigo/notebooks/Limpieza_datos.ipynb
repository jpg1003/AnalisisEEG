# %% [markdown]
# # Titulo

# %% [markdown]
# ## Explicacion

# %%
# %run Importaciones.ipynb
# %run Variables_Clases.ipynb

# %% [markdown]
# * **Compruebo si leo bien el archivo de datos datosEEGTotal.csv**

# %%
pd.read_csv('../datos/datosEEGTotal.csv', sep=';')
# Out:
#      Timestamp  Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  \
# 0        54127         84          48   25253  14225      3441       4172
# 1        55056         78          60    4946   5021      8879      13002
# 2        56038         66          75  102896  14838     12817       8565
# 3        57043         61          87   57763  12541      6173       5120
# 4        58203         37          84   21560  74162     11297       9217
# ..         ...        ...         ...     ...    ...       ...        ...
# 721     348567         81          37    4088  13782       756       5536
# 722     355018         84          20    3490  13947      2299       2051
# 723     358034         84          38    3619   8525      5623       6665
# 724     361108         83          51  116972   5464      1405       6395
# 725     362635         57          44  120133  59585      2946       1584
#
#      LowBeta  HighBeta  LowGamma  HighGamma  Signal      Key
# ...

# %% [markdown]
# * **Guardo los datos en datosEEGTotal_csv**

# %%
datosEEGTotal_csv = pd.read_csv('../datos/datosEEGTotal.csv', sep=';')

# %% [markdown]
# * **Compruebo los datos en el dataset datosEEGTotal_csv**

# %%
print()
print(color.BOLD +  color.UNDERLINE + color.BLUE + "Importo los datos del csv aportado para el TFG" + color.END)
print()
display(datosEEGTotal_csv.head())
# Out:
# Importo los datos del csv aportado para el TFG
#    Timestamp  Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  \
# 0      54127         84          48   25253  14225      3441       4172
# 1      55056         78          60    4946   5021      8879      13002
# 2      56038         66          75  102896  14838     12817       8565
# 3      57043         61          87   57763  12541      6173       5120
# 4      58203         37          84   21560  74162     11297       9217
#
#    LowBeta  HighBeta  LowGamma  HighGamma  Signal      Key
# 0     1881      9630      6863       5745       0  LButton
# 1      879      6367      4314       3150       0      NaN
# 2     2890     14525      9144      23072       0      NaN
# 3     3238     10192      9048       6663       0      NaN
# 4     4844      1945      2644       1678       0      NaN

# %% [markdown]
# * **Examino cuantos datos estan perdidos en el dataset datosEEGTotal_csv**

# %%
print()
print(color.BOLD +  color.UNDERLINE + color.BLUE + "Reviso los datos para identificar si hay nulos en el dataframe" + color.END )
print()

datosEEGTotal_csv.info()

print()
print(color.BOLD +  color.UNDERLINE + color.RED + "Se identifican por cada columna 726 entradas.")
print("Para la columna Key se muestran 513 no nulos, por lo tanto hay 213 nulos para esta columna key" + color.END )
print()
# Out:
# Reviso los datos para identificar si hay nulos en el dataframe
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 726 entries, 0 to 725
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamp   726 non-null    int64
#  1   Attention   726 non-null    int64
#  2   Meditation  726 non-null    int64
#  3   Delta       726 non-null    int64
#  4   Theta       726 non-null    int64
#  5   LowAlpha    726 non-null    int64
#  6   HighAlpha   726 non-null    int64
#  7   LowBeta     726 non-null    int64
#  8   HighBeta    726 non-null    int64
#  9   LowGamma    726 non-null    int64
#  10  HighGamma   726 non-null    int64
#  11  Signal      726 non-null    int64
#  12  Key         513 non-null    object
# dtypes: int64(12), object(1)
# memory usage: 73.9+ KB
#
# Se identifican por cada columna 726 entradas.
# Para la columna Key se muestran 513 no nulos, por lo tanto hay 213 nulos para esta columna key

# %% [markdown]
# Para los 726 registros, indica para cada columna los datos que no son nulos para la columna Key existen 513 no nulos, por lo tanto, hay 213 nulos

# %% [markdown]
# * **Compruebo los datos missing en la columna Key**

# %% [markdown]
# * **Reemplazo los datos missing en la columna Key y lo guardo en otro dataset**

# %%
print()
print(color.BOLD +  color.UNDERLINE + color.BLUE + "Reemplazo los datos nulos de la columna Key por la palabra Nothing con fillna()" + color.END )
print()

datosEEGTotal_clean = datosEEGTotal_csv.fillna("Nothing")

print()
print(color.BOLD +  color.UNDERLINE + color.RED + "Ya no se idenfifican nulos en ninguna columna" + color.END )
print()
# Out:
# Reemplazo los datos nulos de la columna Key por la palabra Nothing con fillna()
#
#
# Ya no se idenfifican nulos en ninguna columna

# %% [markdown]
# * **Examino cuantos datos estan perdidos en el dataset datosEEGTotalRelleno**

# %%
datosEEGTotal_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 726 entries, 0 to 725
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamp   726 non-null    int64
#  1   Attention   726 non-null    int64
#  2   Meditation  726 non-null    int64
#  3   Delta       726 non-null    int64
#  4   Theta       726 non-null    int64
#  5   LowAlpha    726 non-null    int64
#  6   HighAlpha   726 non-null    int64
#  7   LowBeta     726 non-null    int64
#  8   HighBeta    726 non-null    int64
#  9   LowGamma    726 non-null    int64
#  10  HighGamma   726 non-null    int64
#  11  Signal      726 non-null    int64
#  12  Key         726 non-null    object
# dtypes: int64(12), object(1)
# memory usage: 73.9+ KB

# %% [markdown]
# No hay ningun dato perdido en el nuevo dataset

# %% [markdown]
# * **Examino si hay datos con diferentes nombres para unificarlos en el dataset datosEEGTotal_clean**

# %%
print()
print(color.BOLD +  color.UNDERLINE + color.BLUE + "Reviso que datos hay en la columna Key, identicandolos por cada uno de sus valores" + color.END )
print()

display(datosEEGTotal_clean.groupby('Key').Key.count())
# Out:
# Reviso que datos hay en la columna Key, identicandolos por cada uno de sus valores
# Key
# Down       118
# LButton      6
# Left       126
# Nothing    213
# Right      117
# Up         146
# Name: Key, dtype: int64

# %% [markdown]
# LButton y Left se podrian unificar en Left para seguir la nomenclatura de las otras agrupaciones

# %% [markdown]
# * **Modifico en la columna Key los nombres que sean LButton por Left y creo nuevo dataset datosEEGTotal**

# %%
print()
print(color.BOLD +  color.UNDERLINE + color.RED + "Reemplazo los datos identificados como LButton por Left para unificar los datos" + color.END )
print()

datosEEGTotal = datosEEGTotal_clean.replace({"LButton": 'Left'})
# Out:
# Reemplazo los datos identificados como LButton por Left para unificar los datos

# %% [markdown]
# * **Examino si han quedado datos con diferentes nombres para unificarlos en el nuevo dataset datosEEGTotal**

# %%
display (datosEEGTotal.groupby('Key').Key.count())
# Out:
# Key
# Down       118
# Left       132
# Nothing    213
# Right      117
# Up         146
# Name: Key, dtype: int64

# %%
datosEEGTotal.Key.unique() #Tambien se podria revisar con unique()
# Out:
# array(['Left', 'Nothing', 'Up', 'Down', 'Right'], dtype=object)

# %% [markdown]
# * **Los datos en el datasaet ya estarian unificados y rellenos.**

# %%
datosEEGTotal.head()
# Out:
#    Timestamp  Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  \
# 0      54127         84          48   25253  14225      3441       4172
# 1      55056         78          60    4946   5021      8879      13002
# 2      56038         66          75  102896  14838     12817       8565
# 3      57043         61          87   57763  12541      6173       5120
# 4      58203         37          84   21560  74162     11297       9217
#
#    LowBeta  HighBeta  LowGamma  HighGamma  Signal      Key
# 0     1881      9630      6863       5745       0     Left
# 1      879      6367      4314       3150       0  Nothing
# 2     2890     14525      9144      23072       0  Nothing
# 3     3238     10192      9048       6663       0  Nothing
# 4     4844      1945      2644       1678       0  Nothing

# %% [markdown]
# * **Importo pyplot y numpy.**

# %%
print()
print(color.BOLD +  color.UNDERLINE + color.RED + "Para que los datos de Key sean todos de la misma voy a modificarlos" + color.END )
print(color.BOLD +  color.UNDERLINE + color.RED + "Imprimo tanto los datos nuevos como los valores unicos del dataframe para Key" + color.END )
print()
datosEEGFinal1 = datosEEGTotal.replace({'Left': "04"})
datosEEGFinal2 = datosEEGFinal1.replace({'Right': "02"})
datosEEGFinal3 = datosEEGFinal2.replace({'Up': "01"})
datosEEGFinal4 = datosEEGFinal3.replace({'Down': "03"})
datosEEGTotal = datosEEGFinal4.replace({'Nothing': "00"})

display(datosEEGTotal.Key.unique())
display(datosEEGTotal.head())
# Out:
# Para que los datos de Key sean todos de la misma voy a modificarlos
# Imprimo tanto los datos nuevos como los valores unicos del dataframe para Key
# array(['LB', 'CT', 'UB', 'DB', 'RB'], dtype=object)
#    Timestamp  Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  \
# 0      54127         84          48   25253  14225      3441       4172
# 1      55056         78          60    4946   5021      8879      13002
# 2      56038         66          75  102896  14838     12817       8565
# 3      57043         61          87   57763  12541      6173       5120
# 4      58203         37          84   21560  74162     11297       9217
#
#    LowBeta  HighBeta  LowGamma  HighGamma  Signal Key
# 0     1881      9630      6863       5745       0  LB
# 1      879      6367      4314       3150       0  CT
# 2     2890     14525      9144      23072       0  CT
# 3     3238     10192      9048       6663       0  CT
# 4     4844      1945      2644       1678       0  CT

# %%
print()
print(color.BOLD +  color.UNDERLINE + color.BLUE + "Imprimo todos los valores del Datframe" + color.END )
print()
# Out:
# Imprimo todos los valores del Datframe

# %%
datosEEGTotal.plot()
# Out:
# <Axes: >

# %%
print()
print(color.BOLD +  color.UNDERLINE + color.BLUE + "Imprimo los datos de Timestamp porque en la impresion anterior el dibujo es en sierra y en datos de tiempo la grafica deberia ser continua y ascendente" + color.END )
print()

datosEEGTotal["Timestamp"].plot()

print()
print(color.BOLD +  color.UNDERLINE + color.RED + "Efectivamente se comprueba que el experimento parace que esta dividido en 4 experimentos" + color.END )
print(color.BOLD +  color.UNDERLINE + color.RED + "Divido los datos iniciales en los 4 experimentos" + color.END )
print()
# Out:
# Imprimo los datos de Timestamp porque en la impresion anterior el dibujo es en sierra y en datos de tiempo la grafica deberia ser continua y ascendente
#
#
# Efectivamente se comprueba que el experimento parace que esta dividido en 4 experimentos
# Divido los datos iniciales en los 4 experimentos

# %% [markdown]
# * **Parecen cuatro pruebas en un archivos** *

# %%
datosEEGTotal1 = datosEEGTotal.sort_values(by = 'Timestamp')

# %%
datosEEGTotal1
# Out:
#      Timestamp  Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  \
# 0        54127         84          48   25253  14225      3441       4172
# 1        55056         78          60    4946   5021      8879      13002
# 2        56038         66          75  102896  14838     12817       8565
# 307      56870         84          74   84812  39509     12758      14324
# 3        57043         61          87   57763  12541      6173       5120
# ..         ...        ...         ...     ...    ...       ...        ...
# 721     348567         81          37    4088  13782       756       5536
# 722     355018         84          20    3490  13947      2299       2051
# 723     358034         84          38    3619   8525      5623       6665
# 724     361108         83          51  116972   5464      1405       6395
# 725     362635         57          44  120133  59585      2946       1584
#
#      LowBeta  HighBeta  LowGamma  HighGamma  Signal Key
# ...

# %%
#datosEEGTotal1["Timestamp"].plot()

# %%
#datosEEGTotal1.plot()

# %%
#datosEEGTotal1.drop(['Timestamp'],axis=1).plot(kind="line",subplots=True, sharex=False, figsize=(30,30),xlim=0)
#plt.show()

# %%
last_timestamp = None

file_counter = 1

df_segment = pd.DataFrame(columns=datosEEGTotal.columns)

# Itera sobre el DataFrame
for index, row in datosEEGTotal.iterrows():
    current_timestamp = row['Timestamp']
    
    # Si es el primer registro o si el timestamp actual es menor al anterior, crea un nuevo DataFrame y guarda el segmento anterior en un archivo
    if last_timestamp is None or current_timestamp < last_timestamp:
        if last_timestamp is not None:
            # Guarda el DataFrame anterior en un archivo
            df_segment.to_csv(f'../datos/experimento_{file_counter}.csv', index=False)
            file_counter += 1
        
        # Inicializa un nuevo DataFrame para el nuevo segmento
        df_segment = pd.DataFrame(columns=datosEEGTotal.columns)
    
    # Añade la fila actual al DataFrame del segmento actual
    df_segment = pd.concat([df_segment, row.to_frame().T])

    # Actualiza el timestamp anterior
    last_timestamp = current_timestamp

# Guarda el último segmento en un archivo
if not df_segment.empty:
    df_segment.to_csv(f'../datos/experimento_{file_counter}.csv', index=False)

# %%
print()
print(color.BOLD +  color.UNDERLINE + color.BLUE + "Guardo los 4 experimentos como csv, en la carpeta /dato y con nombres experimento_x " + color.END )

print()
# Out:
# Guardo los 4 experimentos como csv, en la carpeta /dato y con nombres experimento_x

# %%
#datosEEG = datosEEGTotal.drop (['Timestamp','Signal'], axis = 1)

# %%
#datosEEG

# %%
#datosEEG.plot(kind="line",subplots=True, sharex=False, figsize=(30,30),xlim=0)
#plt.show()

# %%
#datosEEGFinal

# %%
print()
print(color.BOLD +  color.UNDERLINE + color.BLUE + "Importo los 4 CSV para diferenciar cada uno de los experimentos y compruebo cual de los 4 tiene mas datos" + color.END )

print()
# Out:
# Importo los 4 CSV para diferenciar cada uno de los experimentos y compruebo cual de los 4 tiene mas datos

# %%
experimento_1 = pd.read_csv('../datos/experimento_1.csv', sep=',')
experimento_2 = pd.read_csv('../datos/experimento_2.csv', sep=',')
experimento_3 = pd.read_csv('../datos/experimento_3.csv', sep=',')
experimento_4 = pd.read_csv('../datos/experimento_4.csv', sep=',')

# %%
experimentos = [experimento_1, experimento_2, experimento_3, experimento_4]

for i, experimento in enumerate(experimentos, 1):
    print("Experimento", i, ":", experimento.shape[0], "filas")
# Out:
# Experimento 1 : 138 filas
# Experimento 2 : 169 filas
# Experimento 3 : 203 filas
# Experimento 4 : 216 filas

# %%
print()
print(color.BOLD +  color.UNDERLINE + color.BLUE + "A partir de ahora trabajaré con el Experimento_4 que es el que tiene mas datos" + color.END )

print()
# Out:
# A partir de ahora trabajaré con el Experimento_4 que es el que tiene mas datos

# %%
print()
print(color.BOLD +  color.UNDERLINE + color.BLUE + "Imprimo los datos del Experimento 4" + color.END )

print()
experimento_4.plot()
#experimento_4.plot(kind="line",subplots=True, sharex=False, figsize=(30,30),xlim=0)
#plt.show()
# Out:
# Imprimo los datos del Experimento 4
# <Axes: >

# %%
display(experimento_4.head())
# Out:
#    Timestamp  Attention  Meditation   Delta   Theta  LowAlpha  HighAlpha  \
# 0     123009         48          21  468675  174202      8577      19305
# 1     123120         47          30   98163   25886     18034      23444
# 2     124618         40          38  111774   21909      6006       1006
# 3     125430         37          50  142530   22248      9191       6086
# 4     125981         48          54   58951    4755       965       1237
#
#    LowBeta  HighBeta  LowGamma  HighGamma  Signal Key
# 0    17146     23426     29425      10122       0  LB
# 1    10977     18521     15862      14097       0  CT
# 2     6429      3344      7732       1616       0  CT
# 3     5007      7385      5564       3634       0  CT
# 4     3029      4567      3496        983       0  CT

# %%
print()
print(color.BOLD +  color.UNDERLINE + color.BLUE + "Con describe() veo que tipos de datos hay en el dataframe" + color.END )

print()

display(experimento_4.describe())
# Out:
# Con describe() veo que tipos de datos hay en el dataframe
#            Timestamp   Attention  Meditation         Delta         Theta  \
# count     216.000000  216.000000  216.000000  2.160000e+02  2.160000e+02
# mean   238406.712963   81.611111   39.879630  5.494462e+04  1.948519e+04
# std     66348.457079   17.331962   14.214776  1.803181e+05  8.459396e+04
# min    123009.000000   26.000000    7.000000  9.410000e+02  8.140000e+02
# 25%    184398.250000   70.000000   33.000000  4.670250e+03  4.392000e+03
# 50%    238022.000000   87.000000   39.000000  7.633000e+03  7.429000e+03
# 75%    294440.750000   96.000000   50.000000  1.409700e+04  1.273275e+04
# max    362635.000000  100.000000   84.000000  1.534038e+06  1.193321e+06
#
#            LowAlpha     HighAlpha       LowBeta      HighBeta      LowGamma  \
# count    216.000000    216.000000    216.000000    216.000000    216.000000
# mean    5060.342593   5030.037037   5954.703704  22500.550926  22085.189815
# ...

# %%
print()
print(color.BOLD +  color.UNDERLINE + color.RED + "Me fijo en la media de Signal y compruebo que es 0, por lo tanto esta columna se puede eliminar porque no aporta valor a los analisis y lo hago para los demas experimentos" + color.END )

print()

experimento_4 = experimento_4.drop(['Signal'],axis=1)
experimento_3 = experimento_3.drop(['Signal'],axis=1)
experimento_2 = experimento_2.drop(['Signal'],axis=1)
experimento_1 = experimento_1.drop(['Signal'],axis=1)

display(experimento_4.head())
display(experimento_3.head())
display(experimento_2.head())
display(experimento_1.head())
# Out:
# Me fijo en la media de Signal y compruebo que es 0, por lo tanto esta columna se puede eliminar porque no aporta valor a los analisis y lo hago para los demas experimentos
#    Timestamp  Attention  Meditation   Delta   Theta  LowAlpha  HighAlpha  \
# 0     123009         48          21  468675  174202      8577      19305
# 1     123120         47          30   98163   25886     18034      23444
# 2     124618         40          38  111774   21909      6006       1006
# 3     125430         37          50  142530   22248      9191       6086
# 4     125981         48          54   58951    4755       965       1237
#
#    LowBeta  HighBeta  LowGamma  HighGamma Key
# 0    17146     23426     29425      10122  LB
# 1    10977     18521     15862      14097  CT
# 2     6429      3344      7732       1616  CT
# 3     5007      7385      5564       3634  CT
# 4     3029      4567      3496        983  CT
#    Timestamp  Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  \
# ...

# %%
experimento_1.to_csv('../datos/experimento_1_clean.csv', index=False)
experimento_2.to_csv('../datos/experimento_2_clean.csv', index=False)
experimento_3.to_csv('../datos/experimento_3_clean.csv', index=False)
experimento_4.to_csv('../datos/experimento_4_clean.csv', index=False)

print()
print(color.BOLD +  color.UNDERLINE + color.RED + "Exporto todos los experimentos a varios csv para tratarlos despues" + color.END )
print()

# %%
experimento_all_clean = pd.concat([experimento_1, experimento_2, experimento_3, experimento_4])

# Guardar el resultado en un archivo CSV
experimento_all_clean.to_csv('../datos/experimento_all_clean.csv', index=False) 

print()
print(color.BOLD +  color.UNDERLINE + color.RED + "Exporto todos los experimentos a un csv para tratarlo despues" + color.END )
print()
