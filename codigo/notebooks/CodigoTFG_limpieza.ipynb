# %% [markdown]
# # Titulo

# %% [markdown]
# ## Explicacion

# %% [markdown]
# ### Posibles comentarios

# %% [markdown]
# * **Importo libreria pandas**

# %%
#importando pandas
import pandas as pd

# %% [markdown]
# * **Compruebo si leo bien el archivo de datos datosEEGTotal.csv**

# %%
pd.read_csv('../datos/datosEEGTotal.csv', sep=';')
# Out:
#      Timestamp  Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  \
# 0        54127         84          48   25253  14225      3441       4172
# 1        55056         78          60    4946   5021      8879      13002
# 2        56038         66          75  102896  14838     12817       8565
# 3        57043         61          87   57763  12541      6173       5120
# 4        58203         37          84   21560  74162     11297       9217
# ..         ...        ...         ...     ...    ...       ...        ...
# 721     348567         81          37    4088  13782       756       5536
# 722     355018         84          20    3490  13947      2299       2051
# 723     358034         84          38    3619   8525      5623       6665
# 724     361108         83          51  116972   5464      1405       6395
# 725     362635         57          44  120133  59585      2946       1584
#
#      LowBeta  HighBeta  LowGamma  HighGamma  Signal      Key
# 0       1881      9630      6863       5745       0  LButton
# 1        879      6367      4314       3150       0      NaN
# 2       2890     14525      9144      23072       0      NaN
# 3       3238     10192      9048       6663       0      NaN
# 4       4844      1945      2644       1678       0      NaN
# ..       ...       ...       ...        ...     ...      ...
# 721     7114     24230     12942      14061       0    Right
# 722     3315     22789     17542       9966       0    Right
# 723     5345     31352     22837      12553       0    Right
# 724     2285      7186      5351       1219       0    Right
# 725     5438      6210      3140       1884       0      NaN
#
# [726 rows x 13 columns]

# %% [markdown]
# * **Guardo los datos en datosEEGTotal_csv**

# %%
datosEEGTotal_csv = pd.read_csv('../datos/datosEEGTotal.csv', sep=';')

# %% [markdown]
# * **Compruebo los datos en el dataset datosEEGTotal_csv**

# %%
datosEEGTotal_csv
# Out:
#      Timestamp  Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  \
# 0        54127         84          48   25253  14225      3441       4172
# 1        55056         78          60    4946   5021      8879      13002
# 2        56038         66          75  102896  14838     12817       8565
# 3        57043         61          87   57763  12541      6173       5120
# 4        58203         37          84   21560  74162     11297       9217
# ..         ...        ...         ...     ...    ...       ...        ...
# 721     348567         81          37    4088  13782       756       5536
# 722     355018         84          20    3490  13947      2299       2051
# 723     358034         84          38    3619   8525      5623       6665
# 724     361108         83          51  116972   5464      1405       6395
# 725     362635         57          44  120133  59585      2946       1584
#
#      LowBeta  HighBeta  LowGamma  HighGamma  Signal      Key
# 0       1881      9630      6863       5745       0  LButton
# 1        879      6367      4314       3150       0      NaN
# 2       2890     14525      9144      23072       0      NaN
# 3       3238     10192      9048       6663       0      NaN
# 4       4844      1945      2644       1678       0      NaN
# ..       ...       ...       ...        ...     ...      ...
# 721     7114     24230     12942      14061       0    Right
# 722     3315     22789     17542       9966       0    Right
# 723     5345     31352     22837      12553       0    Right
# 724     2285      7186      5351       1219       0    Right
# 725     5438      6210      3140       1884       0      NaN
#
# [726 rows x 13 columns]

# %% [markdown]
# * **Examino cuantos datos estan perdidos en el dataset datosEEGTotal_csv**

# %%
datosEEGTotal_csv.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 726 entries, 0 to 725
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamp   726 non-null    int64
#  1   Attention   726 non-null    int64
#  2   Meditation  726 non-null    int64
#  3   Delta       726 non-null    int64
#  4   Theta       726 non-null    int64
#  5   LowAlpha    726 non-null    int64
#  6   HighAlpha   726 non-null    int64
#  7   LowBeta     726 non-null    int64
#  8   HighBeta    726 non-null    int64
#  9   LowGamma    726 non-null    int64
#  10  HighGamma   726 non-null    int64
#  11  Signal      726 non-null    int64
#  12  Key         513 non-null    object
# dtypes: int64(12), object(1)
# memory usage: 73.9+ KB

# %% [markdown]
# Para los 726 registros, indica para cada columna los datos que no son nulos para la columna Key existen 513 no nulos, por lo tanto, hay 213 nulos

# %% [markdown]
# * **Compruebo los datos missing en la columna Key**

# %%
datosEEGTotal_csv[pd.isnull(datosEEGTotal_csv.Key)]
# Out:
#      Timestamp  Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  \
# 1        55056         78          60    4946   5021      8879      13002
# 2        56038         66          75  102896  14838     12817       8565
# 3        57043         61          87   57763  12541      6173       5120
# 4        58203         37          84   21560  74162     11297       9217
# 5        59952         48          63    2540   1384       692        467
# ..         ...        ...         ...     ...    ...       ...        ...
# 717     341968         97          51    1649   4652      1007       4496
# 718     342914         96          53    2355   3428      2653       2048
# 719     343917         93          51    7732   9661      4148       3043
# 720     345017         93          30    6033  11388      1086       1898
# 725     362635         57          44  120133  59585      2946       1584
#
#      LowBeta  HighBeta  LowGamma  HighGamma  Signal  Key
# 1        879      6367      4314       3150       0  NaN
# 2       2890     14525      9144      23072       0  NaN
# 3       3238     10192      9048       6663       0  NaN
# 4       4844      1945      2644       1678       0  NaN
# 5       1313      2271      2560        445       0  NaN
# ..       ...       ...       ...        ...     ...  ...
# 717     1952     51386     46310      19608       0  NaN
# 718     3748     23375     28816      10428       0  NaN
# 719     1962     29014     50664      24171       0  NaN
# 720     3777     22194     34869       4480       0  NaN
# 725     5438      6210      3140       1884       0  NaN
#
# [213 rows x 13 columns]

# %% [markdown]
# * **Reemplazo los datos missing en la columna Key y lo guardo en otro dataset**

# %%
datosEEGTotal_clean = datosEEGTotal_csv.fillna("Nothing")

# %% [markdown]
# * **Examino cuantos datos estan perdidos en el dataset datosEEGTotalRelleno**

# %%
datosEEGTotal_clean.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 726 entries, 0 to 725
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamp   726 non-null    int64
#  1   Attention   726 non-null    int64
#  2   Meditation  726 non-null    int64
#  3   Delta       726 non-null    int64
#  4   Theta       726 non-null    int64
#  5   LowAlpha    726 non-null    int64
#  6   HighAlpha   726 non-null    int64
#  7   LowBeta     726 non-null    int64
#  8   HighBeta    726 non-null    int64
#  9   LowGamma    726 non-null    int64
#  10  HighGamma   726 non-null    int64
#  11  Signal      726 non-null    int64
#  12  Key         726 non-null    object
# dtypes: int64(12), object(1)
# memory usage: 73.9+ KB

# %% [markdown]
# No hay ningun dato perdido en el nuevo dataset

# %% [markdown]
# * **Examino si hay datos con diferentes nombres para unificarlos en el dataset datosEEGTotal_clean**

# %%
datosEEGTotal_clean.groupby('Key').Key.count()
# Out:
# Key
# Down       118
# LButton      6
# Left       126
# Nothing    213
# Right      117
# Up         146
# Name: Key, dtype: int64

# %% [markdown]
# LButton y Left se podrian unificar en Left para seguir la nomenclatura de las otras agrupaciones

# %% [markdown]
# * **Modifico en la columna Key los nombres que sean LButton por Left y creo nuevo dataset datosEEGTotal**

# %%
datosEEGTotal = datosEEGTotal_clean.replace({"LButton": 'Left'})

# %% [markdown]
# * **Examino si han quedado datos con diferentes nombres para unificarlos en el nuevo dataset datosEEGTotal**

# %%
datosEEGTotal.groupby('Key').Key.count()
# Out:
# Key
# Down       118
# Left       132
# Nothing    213
# Right      117
# Up         146
# Name: Key, dtype: int64

# %%
datosEEGTotal.Key.unique() #Tambien se podria revisar con unique()
# Out:
# array(['Left', 'Nothing', 'Up', 'Down', 'Right'], dtype=object)

# %% [markdown]
# * **Los datos en el datasaet ya estarian unificados y rellenos.**

# %%
datosEEGTotal.head()
# Out:
#    Timestamp  Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  \
# 0      54127         84          48   25253  14225      3441       4172
# 1      55056         78          60    4946   5021      8879      13002
# 2      56038         66          75  102896  14838     12817       8565
# 3      57043         61          87   57763  12541      6173       5120
# 4      58203         37          84   21560  74162     11297       9217
#
#    LowBeta  HighBeta  LowGamma  HighGamma  Signal      Key
# 0     1881      9630      6863       5745       0     Left
# 1      879      6367      4314       3150       0  Nothing
# 2     2890     14525      9144      23072       0  Nothing
# 3     3238     10192      9048       6663       0  Nothing
# 4     4844      1945      2644       1678       0  Nothing

# %% [markdown]
# * **Importo pyplot y numpy.**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
datosEEGTotal.plot()
# Out:
# <Axes: >

# %%
datosEEGTotal["Timestamp"].plot()
# Out:
# <Axes: >

# %% [markdown]
# * **Parecen cuatro pruebas en un archivos** *

# %%
datosEEGTotal1 = datosEEGTotal.sort_values(by = 'Timestamp')

# %%
datosEEGTotal1
# Out:
#      Timestamp  Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  \
# 0        54127         84          48   25253  14225      3441       4172
# 1        55056         78          60    4946   5021      8879      13002
# 2        56038         66          75  102896  14838     12817       8565
# 307      56870         84          74   84812  39509     12758      14324
# 3        57043         61          87   57763  12541      6173       5120
# ..         ...        ...         ...     ...    ...       ...        ...
# 721     348567         81          37    4088  13782       756       5536
# 722     355018         84          20    3490  13947      2299       2051
# 723     358034         84          38    3619   8525      5623       6665
# 724     361108         83          51  116972   5464      1405       6395
# 725     362635         57          44  120133  59585      2946       1584
#
#      LowBeta  HighBeta  LowGamma  HighGamma  Signal      Key
# 0       1881      9630      6863       5745       0     Left
# 1        879      6367      4314       3150       0  Nothing
# 2       2890     14525      9144      23072       0  Nothing
# 307     8166      7849      5076       2988       0     Left
# 3       3238     10192      9048       6663       0  Nothing
# ..       ...       ...       ...        ...     ...      ...
# 721     7114     24230     12942      14061       0    Right
# 722     3315     22789     17542       9966       0    Right
# 723     5345     31352     22837      12553       0    Right
# 724     2285      7186      5351       1219       0    Right
# 725     5438      6210      3140       1884       0  Nothing
#
# [726 rows x 13 columns]

# %%
datosEEGTotal1["Timestamp"].plot()
# Out:
# <Axes: >

# %%
datosEEGTotal1.plot()
# Out:
# <Axes: >

# %%
datosEEGTotal1.drop(['Timestamp'],axis=1).plot(kind="line",subplots=True, sharex=False, figsize=(30,30),xlim=0)
plt.show()

# %%
last_timestamp = None

file_counter = 1

df_segment = pd.DataFrame(columns=datosEEGTotal.columns)

# Itera sobre el DataFrame
for index, row in datosEEGTotal.iterrows():
    current_timestamp = row['Timestamp']
    
    # Si es el primer registro o si el timestamp actual es menor al anterior, crea un nuevo DataFrame y guarda el segmento anterior en un archivo
    if last_timestamp is None or current_timestamp < last_timestamp:
        if last_timestamp is not None:
            # Guarda el DataFrame anterior en un archivo
            df_segment.to_csv(f'../datos/experimento_{file_counter}.csv', index=False)
            file_counter += 1
        
        # Inicializa un nuevo DataFrame para el nuevo segmento
        df_segment = pd.DataFrame(columns=datosEEGTotal.columns)
    
    # Añade la fila actual al DataFrame del segmento actual
    df_segment = pd.concat([df_segment, row.to_frame().T])

    # Actualiza el timestamp anterior
    last_timestamp = current_timestamp

# Guarda el último segmento en un archivo
if not df_segment.empty:
    df_segment.to_csv(f'../datos/experimento_{file_counter}.csv', index=False)

# %%
datosEEG = datosEEGTotal.drop (['Timestamp','Signal'], axis = 1)

# %%
datosEEG
# Out:
#      Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  LowBeta  \
# 0           84          48   25253  14225      3441       4172     1881
# 1           78          60    4946   5021      8879      13002      879
# 2           66          75  102896  14838     12817       8565     2890
# 3           61          87   57763  12541      6173       5120     3238
# 4           37          84   21560  74162     11297       9217     4844
# ..         ...         ...     ...    ...       ...        ...      ...
# 721         81          37    4088  13782       756       5536     7114
# 722         84          20    3490  13947      2299       2051     3315
# 723         84          38    3619   8525      5623       6665     5345
# 724         83          51  116972   5464      1405       6395     2285
# 725         57          44  120133  59585      2946       1584     5438
#
#      HighBeta  LowGamma  HighGamma      Key
# 0        9630      6863       5745     Left
# 1        6367      4314       3150  Nothing
# 2       14525      9144      23072  Nothing
# 3       10192      9048       6663  Nothing
# 4        1945      2644       1678  Nothing
# ..        ...       ...        ...      ...
# 721     24230     12942      14061    Right
# 722     22789     17542       9966    Right
# 723     31352     22837      12553    Right
# 724      7186      5351       1219    Right
# 725      6210      3140       1884  Nothing
#
# [726 rows x 11 columns]

# %%
datosEEG.plot(kind="line",subplots=True, sharex=False, figsize=(30,30),xlim=0)
plt.show()

# %%
datosEEGFinal1 = datosEEG.replace({'Left': 1})
datosEEGFinal2 = datosEEGFinal1.replace({'Right': 2})
datosEEGFinal3 = datosEEGFinal2.replace({'Up': 3})
datosEEGFinal4 = datosEEGFinal3.replace({'Down': 4})
datosEEGFinal = datosEEGFinal4.replace({'Nothing': 0})

# %%
datosEEGFinal
# Out:
#      Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  LowBeta  \
# 0           84          48   25253  14225      3441       4172     1881
# 1           78          60    4946   5021      8879      13002      879
# 2           66          75  102896  14838     12817       8565     2890
# 3           61          87   57763  12541      6173       5120     3238
# 4           37          84   21560  74162     11297       9217     4844
# ..         ...         ...     ...    ...       ...        ...      ...
# 721         81          37    4088  13782       756       5536     7114
# 722         84          20    3490  13947      2299       2051     3315
# 723         84          38    3619   8525      5623       6665     5345
# 724         83          51  116972   5464      1405       6395     2285
# 725         57          44  120133  59585      2946       1584     5438
#
#      HighBeta  LowGamma  HighGamma  Key
# 0        9630      6863       5745    1
# 1        6367      4314       3150    0
# 2       14525      9144      23072    0
# 3       10192      9048       6663    0
# 4        1945      2644       1678    0
# ..        ...       ...        ...  ...
# 721     24230     12942      14061    2
# 722     22789     17542       9966    2
# 723     31352     22837      12553    2
# 724      7186      5351       1219    2
# 725      6210      3140       1884    0
#
# [726 rows x 11 columns]

# %%
datosEEGFinal.corr()
# Out:
#             Attention  Meditation     Delta     Theta  LowAlpha  HighAlpha  \
# Attention    1.000000   -0.234220 -0.274706 -0.217739 -0.144125  -0.119216
# Meditation  -0.234220    1.000000  0.015716 -0.026580  0.070157   0.049818
# Delta       -0.274706    0.015716  1.000000  0.518175  0.411938   0.446305
# Theta       -0.217739   -0.026580  0.518175  1.000000  0.698004   0.693608
# LowAlpha    -0.144125    0.070157  0.411938  0.698004  1.000000   0.943092
# HighAlpha   -0.119216    0.049818  0.446305  0.693608  0.943092   1.000000
# LowBeta     -0.043565    0.000421  0.284101  0.522481  0.755744   0.768055
# HighBeta     0.115263   -0.220659  0.267917  0.538061  0.678965   0.692525
# LowGamma     0.173977   -0.292023  0.128772  0.334154  0.407958   0.387557
# HighGamma    0.077441   -0.161420  0.175052  0.408908  0.562585   0.546805
# Key          0.201666   -0.008808 -0.191331 -0.060569 -0.040301  -0.039498
#
#              LowBeta  HighBeta  LowGamma  HighGamma       Key
# Attention  -0.043565  0.115263  0.173977   0.077441  0.201666
# Meditation  0.000421 -0.220659 -0.292023  -0.161420 -0.008808
# Delta       0.284101  0.267917  0.128772   0.175052 -0.191331
# Theta       0.522481  0.538061  0.334154   0.408908 -0.060569
# LowAlpha    0.755744  0.678965  0.407958   0.562585 -0.040301
# HighAlpha   0.768055  0.692525  0.387557   0.546805 -0.039498
# LowBeta     1.000000  0.739069  0.495925   0.744354 -0.020281
# HighBeta    0.739069  1.000000  0.735810   0.786402 -0.033106
# LowGamma    0.495925  0.735810  1.000000   0.765329 -0.051777
# HighGamma   0.744354  0.786402  0.765329   1.000000 -0.028003
# Key        -0.020281 -0.033106 -0.051777  -0.028003  1.000000

# %%
DatosEntrada= datosEEGFinal[['Attention', 'Meditation', 'Delta', 'Theta', 'LowAlpha', 'HighAlpha', 'LowBeta', 'HighBeta', 'LowGamma', 'HighGamma']] 
Key= datosEEGFinal[['Key']]

# %%
# Out:
#      Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  LowBeta  \
# 0           84          48   25253  14225      3441       4172     1881
# 1           78          60    4946   5021      8879      13002      879
# 2           66          75  102896  14838     12817       8565     2890
# 3           61          87   57763  12541      6173       5120     3238
# 4           37          84   21560  74162     11297       9217     4844
# ..         ...         ...     ...    ...       ...        ...      ...
# 721         81          37    4088  13782       756       5536     7114
# 722         84          20    3490  13947      2299       2051     3315
# 723         84          38    3619   8525      5623       6665     5345
# 724         83          51  116972   5464      1405       6395     2285
# 725         57          44  120133  59585      2946       1584     5438
#
#      HighBeta  LowGamma  HighGamma
# 0        9630      6863       5745
# 1        6367      4314       3150
# 2       14525      9144      23072
# 3       10192      9048       6663
# 4        1945      2644       1678
# ..        ...       ...        ...
# 721     24230     12942      14061
# 722     22789     17542       9966
# 723     31352     22837      12553
# 724      7186      5351       1219
# 725      6210      3140       1884
#
# [726 rows x 10 columns]
