# %% [markdown]
# <img style="float:left" width="70%" src="../../documentacion/imagenes/escudo_COLOR_1L_DCHA.png">
# <img style="float:right" width="10%" src="../../documentacion/imagenes/PythonLogo.svg">
# <br style="clear:both;">
#
#
# <h2 style="display: inline-block; padding: 4mm; padding-left: 2em; background-color: navy; line-height: 1.3em; color: white; border-radius: 10px;">9.5.Deep_Learning-LSTM(Aumento_Datos_SlidingWindows)</h2>
#
#
#
# ## Estudiante:
#
# - Jose Luis Perez Gomez

# %% [markdown]
# ## Seleccionar que tipo de ejecucion se va a realizar:
#
# ## AUTOMATICA o MANUAL (por defecto AUTOMATICA).

# %%
# escribir entre parentesis AUTOMATICA o MANUAL

EJECUCION = "AUTOMATICA"

# %%
# en esta celda no ha de ser modificada 

if EJECUCION == "MANUAL":
    # %run 3.Importaciones.ipynb

# %run 4.VariablesClases.ipynb

# %%
datosEEG_seg1_standarizado = pd.read_csv('../datos/csv/seg1_stscaler.csv', sep=',')
datosEEG_std_after_resampled = pd.read_csv('../datos/csv/datosEEG_std_after_resampled.csv', sep=',')
datosEEG_std_before_resampled = pd.read_csv('../datos/csv/datosEEG_std_before_resampled.csv', sep=',')
datosEEG_std_tres_segmentos = pd.read_csv('../datos/csv/datosEEG_std_tres_segmentos.csv', sep=',')

datosEEG_all = [datosEEG_std_after_resampled, datosEEG_std_before_resampled]

nombre_clases = valores_key(datosEEG_seg1_standarizado)

# %% [markdown]
# # LSTM (Long short-term memory)

# %%
model_lstm_rs_sw = crear_modelo_LSTM(TIMESTEPS, FEATURES, NUM_CLASES)

display(HTML(html_h5('Entreno los conjuntos de datos para el  modelo LSTM con aumento de datos: ', 'purple')))
display(HTML(html_h5('Se imprimen a tiempo real las ejecuciones de cada conjunto de datos: ', 'blue')))
# Out:
# C:\Users\Casa\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h5><font color=purple>Entreno los conjuntos de datos para el  modelo LSTM con aumento de datos: </h5>
#
#     </body>
#     </html>
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h5><font color=blue>Se imprimen a tiempo real las ejecuciones de cada conjunto de datos: </h5>
#
#     </body>
#     </html>

# %%
accuracy_score_lstm_rs_sw = []
accuracy_score_test_lstm_rs_sw =[]
matriz_confusion_lstm_rs_sw = []
matriz_confusion_test_lstm_rs_sw = []
total_simple_lstm_rs_sw_trained = []

for dataset in datosEEG_all:   
       
    train_datos, val_datos, test_datos = dividir_datos_deep(dataset, TARGET)
    
    columns = train_datos.columns[train_datos.columns != TARGET]
    
    X_train, y_train = preparar_ventanas(train_datos[columns], train_datos[TARGET], WINDOWS_SIZE, OVERLAP )
    X_val, y_val = preparar_ventanas(val_datos[columns], val_datos[TARGET], WINDOWS_SIZE, OVERLAP )
    X_test, y_test = preparar_ventanas(test_datos[columns], test_datos[TARGET], WINDOWS_SIZE, OVERLAP )
            
    # Entrenar el modelo
    model_lstm_trained_rs_sw = model_lstm_rs_sw.fit(X_train, y_train, epochs=EPOCHS, batch_size=BACH_SIZE, validation_data= (X_val, y_val), callbacks=[early_stopping, REDUCE_RL, model_checkpoint, plot_learning])
    
    y_pred = model_lstm_rs_sw.predict(X_val)
    y_pred_classes = np.argmax(y_pred, axis=1)
    
    y_pred_test = model_lstm_rs_sw.predict(X_test)
    y_pred_classes_test = np.argmax(y_pred_test, axis=1)

    accuracy_score_lstm_rs_sw.append(accuracy_score(y_val, y_pred_classes))
    matriz_confusion_lstm_rs_sw.append(confusion_matrix(y_val, y_pred_classes))
    
    accuracy_score_test_lstm_rs_sw.append(accuracy_score(y_test, y_pred_classes_test))
    matriz_confusion_test_lstm_rs_sw.append(confusion_matrix(y_test, y_pred_classes_test))
    
    total_simple_lstm_rs_sw_trained.append(model_lstm_trained_rs_sw)
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6349 - loss: 0.9184 - val_accuracy: 0.5787 - val_loss: 1.0193 - learning_rate: 0.0010
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
train_datos, val_datoS =  dividir_datos_deep_sr_wd(datosEEG_std_tres_segmentos, TARGET)
test_datos = datosEEG_seg1_standarizado

X_train, y_train = preparar_ventanas(train_datos[columns], train_datos[TARGET], WINDOWS_SIZE, OVERLAP )
X_val, y_val = preparar_ventanas(val_datos[columns], val_datos[TARGET], WINDOWS_SIZE, OVERLAP )
X_test, y_test = preparar_ventanas(test_datos[columns], test_datos[TARGET], WINDOWS_SIZE, OVERLAP )

# Entrenar el modelo
model_lstm_rs_sw_trained1 = model_lstm_rs_sw.fit(X_train, y_train, epochs=EPOCHS, batch_size=BACH_SIZE, validation_data= (X_val, y_val), callbacks=[early_stopping, REDUCE_RL, model_checkpoint, plot_learning])

y_pred = model_lstm_rs_sw.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)

y_pred_test = model_lstm_rs_sw.predict(X_test)
y_pred_classes_test = np.argmax(y_pred_test, axis=1)

accuracy_score_lstm_rs_sw.append(accuracy_score(y_val, y_pred_classes))
matriz_confusion_lstm_rs_sw.append(confusion_matrix(y_val, y_pred_classes))

accuracy_score_test_lstm_rs_sw.append(accuracy_score(y_test, y_pred_classes_test))
matriz_confusion_test_lstm_rs_sw.append(confusion_matrix(y_test, y_pred_classes_test))

#simple_rnn_loss, simple_rnn_accuracy = model_srnn.evaluate(X_test, y_test)
total_simple_lstm_rs_sw_trained.append(model_lstm_rs_sw_trained1)
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7501 - loss: 0.6393 - val_accuracy: 0.4638 - val_loss: 1.5016 - learning_rate: 0.0010
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
display(HTML(html_h5('Estos son los resultados para Tasa de acierto y su matrices de confusión para el subconjunto de datos validación: ', 'blue')))

datos_lstm_rs_sw = pd.DataFrame(accuracy_score_lstm_rs_sw, columns=['LSTM_RS_SW_VAL'], index=(titulos_all_rs))

display(datos_lstm_rs_sw)

mc_lstm = []

for matrices_lstm in matriz_confusion_lstm_rs_sw:

    mc_lstm.append(pd.DataFrame(matrices_lstm, index=nombre_clases, columns=nombre_clases))

#https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html

# Creo una figura y ejes para dividir el espacio en cuatro subgráficos
fig, axs = plt.subplots(1, 3, figsize=(10, 12))

# Matrices de confusión y títulos para cada subgráfico
dataframes = [mc_lstm[0], mc_lstm[1], mc_lstm[2]]


# Itero sobre los DataFrames y títulos para imprimir matriz de confusión en un subgráfico
for i, (dataframe, titulo) in enumerate(zip(dataframes, titulos_all_rs)):

    ax = axs[i]
   
    # Se crea la impresion de la matriz de confusión y se implime
    disp = ConfusionMatrixDisplay(confusion_matrix=dataframe.values, display_labels=(nombre_clases))
    disp.plot(ax=ax, colorbar=False, cmap='Blues')
    
    # Añado el título al subgráfico
    ax.set_title(titulo)

# Se ajusta el espaciado entre subgráficos
plt.tight_layout()

# Se imprime el gráfico
plt.show()
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h5><font color=blue>Estos son los resultados para Tasa de acierto y su matrices de confusión para el subconjunto de datos validación: </h5>
#
#     </body>
#     </html>
#                       LSTM_RS_SW_VAL
# All Segmentos after         0.723404
# All Segmentos before        0.489362
# Test Datos Reales           0.500000

# %%
display(HTML(html_h5('Imprimo los graficos Tasa de acierto y loss durante los entrenamientos de los modelos : ', 'blue')))

display(HTML(html_h5('Se imprimern en este orden "All Segmentos after", "All Segmentos before", "Test contra Datos Reales" " : ', 'blue')))


# Crear una figura con 6 subgráficos (3 filas y 2 columnas)
fig, axes = plt.subplots(3, 2, figsize=(10, 15))

# Asegurarse de que haya suficiente espacio entre los subgráficos
plt.tight_layout(pad=5.0)

# Alternar entre 'loss' y 'accuracy' para cada par de subgráficos
for idx, history in enumerate(total_simple_lstm_rs_sw_trained[:4]):
    i, j = divmod(idx * 2, 2)
    # Imprimir la gráfica de pérdida en el primer subgráfico del par
    print_chart(axes[i, j], "Model Accuracy", "Epoch", "Accuracy", 
            [history.history['accuracy'], history.history['val_accuracy']], ['Train', 'Val'])
    
    # Imprimir la gráfica de precisión (accuracy) en el segundo subgráfico del par
    i, j = divmod(idx * 2 + 1, 2)
    print_chart(axes[i, j], "Model Loss", "Epoch", "Loss", 
                [history.history['loss'], history.history['val_loss']], ['Train', 'Val'])

# Mostrar todas las gráficas en una sola figura
plt.show()
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h5><font color=blue>Imprimo los graficos Tasa de acierto y loss durante los entrenamientos de los modelos : </h5>
#
#     </body>
#     </html>
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h5><font color=blue>Se imprimern en este orden "All Segmentos after", "All Segmentos before", "Test contra Datos Reales" " : </h5>
#
#     </body>
#     </html>

# %%
display(HTML(html_h5('Estos son los resultados para Tasa de acierto y su matrices de confusión para el subconjutno de datos test: ', 'purple')))

datos_lstm_rs_test_sw = pd.DataFrame(accuracy_score_test_lstm_rs_sw, columns=['LSTM_RS_SW_TEST'], index=(titulos_all_rs))

display(datos_lstm_rs_test_sw)

mc_lstm = []

for matrices_lstm in matriz_confusion_test_lstm_rs_sw:

    mc_lstm.append(pd.DataFrame(matrices_lstm, index=nombre_clases, columns=nombre_clases))

#https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html

# Creo una figura y ejes para dividir el espacio en cuatro subgráficos
fig, axs = plt.subplots(1, 3, figsize=(10, 12))

# Matrices de confusión y títulos para cada subgráfico
dataframes = [mc_lstm[0], mc_lstm[1], mc_lstm[2]]


# Itero sobre los DataFrames y títulos para imprimir matriz de confusión en un subgráfico
for i, (dataframe, titulo) in enumerate(zip(dataframes, titulos_all_rs)):

    ax = axs[i]
   
    # Se crea la impresion de la matriz de confusión y se implime
    disp = ConfusionMatrixDisplay(confusion_matrix=dataframe.values, display_labels=(nombre_clases))
    disp.plot(ax=ax, colorbar=False, cmap='Blues')
    
    # Añado el título al subgráfico
    ax.set_title(titulo)

# Se ajusta el espaciado entre subgráficos
plt.tight_layout()

# Se imprime el gráfico
plt.show()
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h5><font color=purple>Estos son los resultados para Tasa de acierto y su matrices de confusión para el subconjutno de datos test: </h5>
#
#     </body>
#     </html>
#                       LSTM_RS_SW_TEST
# All Segmentos after          0.809091
# All Segmentos before         0.645455
# Test Datos Reales            0.600000

# %%
datos_lstm_rs_test_sw.to_csv(f'../datos/csv/datosEGG_LSTM_RS_SW_test.csv', index=False)
datos_lstm_rs_sw.to_csv(f'../datos/csv/datosEGG_LSTM_RS_SW_val.csv', index=False)
