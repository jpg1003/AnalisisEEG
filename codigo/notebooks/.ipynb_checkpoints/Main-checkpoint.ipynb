# %%
# Creo un entorno virtual
# !python -m venv GII_O_MA_23.37
# !GII_O_MA_23.37\Scripts\activate

# %% [markdown]
# ## Instalo las librerias, realizo las importaciones

# %%
# %%capture
# %run Librerias.ipynb

# %% [markdown]
# ## Importo variables y clases

# %%
# %run Importaciones.ipynb
# %run Variables_Clases.ipynb

# %% [markdown]
# # 1. Limpieza y Normalizacion de Datos

# %% [markdown]
# ## 1.1 Ejecución Notebook Limpieza de Datos

# %%
# %run Limpieza_datos.ipynb
# Out:
# Importo los datos del csv aportado para el TFG
#    Timestamp  Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  \
# 0      54127         84          48   25253  14225      3441       4172
# 1      55056         78          60    4946   5021      8879      13002
# 2      56038         66          75  102896  14838     12817       8565
# 3      57043         61          87   57763  12541      6173       5120
# 4      58203         37          84   21560  74162     11297       9217
#
#    LowBeta  HighBeta  LowGamma  HighGamma  Signal      Key
# 0     1881      9630      6863       5745       0  LButton
# 1      879      6367      4314       3150       0      NaN
# 2     2890     14525      9144      23072       0      NaN
# 3     3238     10192      9048       6663       0      NaN
# 4     4844      1945      2644       1678       0      NaN
# Reviso los datos para identificar si hay nulos en el dataframe
#
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# ## 1.2 Ejecución Notebook Normalizacion de Datos

# %%
# %run Normalizacion.ipynb
# Out:
#      Timestamp  Attention  Meditation   Delta   Theta  LowAlpha  HighAlpha  \
# 0       123009         48          21  468675  174202      8577      19305
# 1       123120         47          30   98163   25886     18034      23444
# 2       124618         40          38  111774   21909      6006       1006
# 3       125430         37          50  142530   22248      9191       6086
# 4       125981         48          54   58951    4755       965       1237
# ..         ...        ...         ...     ...     ...       ...        ...
# 211     348567         81          37    4088   13782       756       5536
# 212     355018         84          20    3490   13947      2299       2051
# 213     358034         84          38    3619    8525      5623       6665
# 214     361108         83          51  116972    5464      1405       6395
# 215     362635         57          44  120133   59585      2946       1584
#
#      LowBeta  HighBeta  LowGamma  HighGamma  Key
# ...

# %% [markdown]
# # 2 Implementacion Modelos Machine y Deep Learning

# %% [markdown]
# ## 2.1 Ejecución Notebook Machine Learning

# %%
# %run Machine_Learning.ipynb
# Out:
#        Knn_holdout  Tree_holdout  Random_holdout
# Exp_1     0.923077      0.846154        0.615385
# Exp_2     0.937500      0.875000        0.500000
# Exp_3     0.800000      0.700000        0.500000
# Exp_4     0.800000      0.750000        0.250000
#        Knn_cross_val  Tree_cross_val  Random_cross_val
# Exp_1       0.921429        0.869048          0.509524
# Exp_2       0.838393        0.825893          0.500893
# Exp_3       0.850000        0.745000          0.440556
# Exp_4       0.773333        0.711667          0.351667
#         Knn_loo  Tree_loo  Random_loo
# Exp_1  0.930769  0.830769    0.530769
# Exp_2  0.929936  0.910828    0.509554
# Exp_3  0.927461  0.746114    0.471503
# Exp_4  0.873737  0.777778    0.429293
#        Knn_holdout  Tree_holdout  Random_holdout  Knn_cross_val  \
# Exp_1     0.923077      0.846154        0.615385       0.921429
# Exp_2     0.937500      0.875000        0.500000       0.838393
# ...
