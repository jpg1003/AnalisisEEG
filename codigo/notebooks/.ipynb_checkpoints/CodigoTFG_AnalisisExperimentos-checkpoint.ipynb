# %% [markdown]
# # Titulo

# %% [markdown]
# ## Explicacion

# %% [markdown]
# ### Posibles comentarios

# %% [markdown]
# * **Importo libreria pandas**

# %%
#importando pandas
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
experimento_1 = pd.read_csv('../datos/experimento_1.csv', sep=',')

# %%
experimento_2 = pd.read_csv('../datos/experimento_2.csv', sep=',')

# %%
experimento_3 = pd.read_csv('../datos/experimento_3.csv', sep=',')

# %%
experimento_4 = pd.read_csv('../datos/experimento_4.csv', sep=',')

# %%
experimento_1
# Out:
#      Timestamp  Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  \
# 0        54127         84          48   25253  14225      3441       4172
# 1        55056         78          60    4946   5021      8879      13002
# 2        56038         66          75  102896  14838     12817       8565
# 3        57043         61          87   57763  12541      6173       5120
# 4        58203         37          84   21560  74162     11297       9217
# ..         ...        ...         ...     ...    ...       ...        ...
# 133     187431         61          70    5690   2701       820       1651
# 134     188460         64          64    8282  10500      1457       2669
# 135     189477         56          60    4616  16668      7561       2408
# 136     190419         60          44   35252  34850      6949       7322
# 137     191448         57          53    3003   8935     10362       2955
#
#      LowBeta  HighBeta  LowGamma  HighGamma  Signal      Key
# ...

# %%
experimento_2
# Out:
#      Timestamp  Attention  Meditation    Delta   Theta  LowAlpha  HighAlpha  \
# 0        57376         93          54    26058    7342      3054       3465
# 1        57388         90          50    14295   13844      1729       4652
# 2        58315         91          30    34117   43817      6749       3596
# 3        59318         77          35    23235   27065      8183      11260
# 4        60344         78          41  1604977   14633     12696      16053
# ..         ...        ...         ...      ...     ...       ...        ...
# 164     219569         61          48     5743   10541      7684       4746
# 165     220590         41          57   369090  165634    130188     123349
# 166     221676         20          80  1185893  112486     64944      36963
# 167     222580         14          81     2943    9414      9693       9878
# 168     223565         14          83    84070    8539      5657       3212
#
# ...

# %%
experimento_3
# Out:
#      Timestamp  Attention  Meditation   Delta   Theta  LowAlpha  HighAlpha  \
# 0        56870         84          74   84812   39509     12758      14324
# 1        57882         78          64   60522   42961     19079      10878
# 2        58914         81          56   19995   32283      1915       4450
# 3        59849         63          67   26830   44722     26228       6476
# 4        60860         64          69  745366   27386     25816       4774
# ..         ...        ...         ...     ...     ...       ...        ...
# 198     255483         41          66  628100  126627     35295      36227
# 199     256014         37          66  811231   24885     10137       1578
# 200     257396         27          63  416717   28424     32543       6994
# 201     258198         23          69  903603   33652      3135       6086
# 202     259033         11          50   67437   30751      1040        875
#
#      LowBeta  HighBeta  LowGamma  HighGamma  Signal      Key
# ...

# %%
experimento_4
# Out:
#      Timestamp  Attention  Meditation   Delta   Theta  LowAlpha  HighAlpha  \
# 0       123009         48          21  468675  174202      8577      19305
# 1       123120         47          30   98163   25886     18034      23444
# 2       124618         40          38  111774   21909      6006       1006
# 3       125430         37          50  142530   22248      9191       6086
# 4       125981         48          54   58951    4755       965       1237
# ..         ...        ...         ...     ...     ...       ...        ...
# 211     348567         81          37    4088   13782       756       5536
# 212     355018         84          20    3490   13947      2299       2051
# 213     358034         84          38    3619    8525      5623       6665
# 214     361108         83          51  116972    5464      1405       6395
# 215     362635         57          44  120133   59585      2946       1584
#
#      LowBeta  HighBeta  LowGamma  HighGamma  Signal      Key
# ...

# %%
experimento_4.plot()
# Out:
# <Axes: >

# %%
experimento_4.plot(kind="line",subplots=True, sharex=False, figsize=(30,30),xlim=0)
plt.show()

# %%
experimento_4.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamp   216 non-null    int64
#  1   Attention   216 non-null    int64
#  2   Meditation  216 non-null    int64
#  3   Delta       216 non-null    int64
#  4   Theta       216 non-null    int64
#  5   LowAlpha    216 non-null    int64
#  6   HighAlpha   216 non-null    int64
#  7   LowBeta     216 non-null    int64
#  8   HighBeta    216 non-null    int64
#  9   LowGamma    216 non-null    int64
#  10  HighGamma   216 non-null    int64
#  11  Signal      216 non-null    int64
#  12  Key         216 non-null    object
# dtypes: int64(12), object(1)
# memory usage: 22.1+ KB

# %%
# Crear el gráfico
plt.figure(figsize=(10, 8))

# Para cada columna en el DataFrame excepto la columna 'Key', trazar los datos
for column in exp_4.columns:
    if column != 'Timestamp':
        if column != 'Key':
            plt.plot(exp_4['Key'], exp_4[column], marker='X', label=column)

# Agregar etiquetas y título
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### análisis de componentes principales (PCA) ###

# %% [markdown]
# ###  normalizacion de los datos, rango de los valores seas coherente. asi la comparacion sera mas acertada. valores similares y coherentes entre si

# %%
experimento_4_1 = experimento_4.replace({'Left': 1})
experimento_4_2 = experimento_4_1.replace({'Right': 2})
experimento_4_3 = experimento_4_2.replace({'Up': 3})
experimento_4_4 = experimento_4_3.replace({'Down': 4})
experimento_4 = experimento_4_4.replace({'Nothing': 0})

# %%
experimento_4
# Out:
#      Timestamp  Attention  Meditation   Delta   Theta  LowAlpha  HighAlpha  \
# 0       123009         48          21  468675  174202      8577      19305
# 1       123120         47          30   98163   25886     18034      23444
# 2       124618         40          38  111774   21909      6006       1006
# 3       125430         37          50  142530   22248      9191       6086
# 4       125981         48          54   58951    4755       965       1237
# ..         ...        ...         ...     ...     ...       ...        ...
# 211     348567         81          37    4088   13782       756       5536
# 212     355018         84          20    3490   13947      2299       2051
# 213     358034         84          38    3619    8525      5623       6665
# 214     361108         83          51  116972    5464      1405       6395
# 215     362635         57          44  120133   59585      2946       1584
#
#      LowBeta  HighBeta  LowGamma  HighGamma  Signal  Key
# ...

# %%
experimento_4.describe()
# Out:
#            Timestamp   Attention  Meditation         Delta         Theta  \
# count     216.000000  216.000000  216.000000  2.160000e+02  2.160000e+02
# mean   238406.712963   81.611111   39.879630  5.494462e+04  1.948519e+04
# std     66348.457079   17.331962   14.214776  1.803181e+05  8.459396e+04
# min    123009.000000   26.000000    7.000000  9.410000e+02  8.140000e+02
# 25%    184398.250000   70.000000   33.000000  4.670250e+03  4.392000e+03
# 50%    238022.000000   87.000000   39.000000  7.633000e+03  7.429000e+03
# 75%    294440.750000   96.000000   50.000000  1.409700e+04  1.273275e+04
# max    362635.000000  100.000000   84.000000  1.534038e+06  1.193321e+06
#
#            LowAlpha     HighAlpha       LowBeta      HighBeta      LowGamma  \
# count    216.000000    216.000000    216.000000    216.000000    216.000000
# mean    5060.342593   5030.037037   5954.703704  22500.550926  22085.189815
# std     6694.244544   6241.816118   4731.517976  11003.476590  11101.887830
# ...

# %%
Simple_experimento_4 = experimento_4
#Escalado simple
Simple_experimento_4['Attention'] = Simple_experimento_4['Attention']/Simple_experimento_4['Attention'].max()

# %%
Simple_experimento_4['Attention']
# Out:
# 0      0.48
# 1      0.47
# 2      0.40
# 3      0.37
# 4      0.48
#        ...
# 211    0.81
# 212    0.84
# 213    0.84
# 214    0.83
# 215    0.57
# Name: Attention, Length: 216, dtype: float64

# %%
MinMax_experimento_4 = experimento_4
#Escalado min-max
MinMax_experimento_4['Attention'] = (MinMax_experimento_4['Attention']-MinMax_experimento_4['Attention'].min())/(MinMax_experimento_4['Attention'].max()-MinMax_experimento_4['Attention'].min())

# %%
MinMax_experimento_4['Attention']
# Out:
# 0      0.297297
# 1      0.283784
# 2      0.189189
# 3      0.148649
# 4      0.297297
#          ...
# 211    0.743243
# 212    0.783784
# 213    0.783784
# 214    0.770270
# 215    0.418919
# Name: Attention, Length: 216, dtype: float64

# %%
ZScore_experimento_4 = experimento_4
#Escalado Z-score
ZScore_experimento_4['Attention'] = (ZScore_experimento_4['Attention']-ZScore_experimento_4['Attention'].mean())/ZScore_experimento_4['Attention'].std()

# %%
ZScore_experimento_4['Attention']
# Out:
# 0     -1.939256
# 1     -1.996953
# 2     -2.400831
# 3     -2.573922
# 4     -1.939256
#          ...
# 211   -0.035259
# 212    0.137831
# 213    0.137831
# 214    0.080135
# 215   -1.419984
# Name: Attention, Length: 216, dtype: float64

# %% [markdown]
# ## Pruebo con dos tipos

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

experimento_4_norm = experimento_4
experimento_4_minmax = experimento_4

# Selecciono las columnas a normalizar
columnas = ['Timestamp','Attention', 'Meditation','Delta', 'Theta', 'LowAlpha', 'HighAlpha', 'LowBeta', 'HighBeta', 'LowGamma', 'HighGamma']

minmax = MinMaxScaler()
#scaler = StandardScaler()


# Normaliza las columnas seleccionadas
#experimento_4_norm[columnas] = scaler.fit_transform(experimento_4_norm[columnas])
experimento_4_minmax[columnas] = minmax.fit_transform(experimento_4_minmax[columnas])

display(experimento_4_minmax[columnas])
# Out:
#      Timestamp  Attention  Meditation     Delta     Theta  LowAlpha  \
# 0     0.000000   0.297297    0.181818  0.305091  0.145398  0.137521
# 1     0.000463   0.283784    0.298701  0.063415  0.021025  0.291121
# 2     0.006715   0.189189    0.402597  0.072294  0.017690  0.095762
# 3     0.010103   0.148649    0.558442  0.092355  0.017974  0.147493
# 4     0.012403   0.297297    0.610390  0.037838  0.003305  0.013887
# ..         ...        ...         ...       ...       ...       ...
# 211   0.941292   0.743243    0.389610  0.002053  0.010875  0.010492
# 212   0.968213   0.783784    0.168831  0.001663  0.011013  0.035554
# 213   0.980799   0.783784    0.402597  0.001747  0.006466  0.089542
# 214   0.993628   0.770270    0.571429  0.075684  0.003899  0.021033
# 215   1.000000   0.418919    0.480519  0.077746  0.049284  0.046062
#
#      HighAlpha   LowBeta  HighBeta  LowGamma  HighGamma
# 0     0.352211  0.559510  0.338937  0.353816   0.279369
# ...

# %%
experimento_4_normalizado = pd.concat([experimento_4_minmax[columnas], experimento_4[['Key']]], axis = 1)
#experimento_4_normalizado = experimento_4_minmax[columnas]

# %%
experimento_4_normalizado
# Out:
#      Timestamp  Attention  Meditation     Delta     Theta  LowAlpha  \
# 0     0.000000   0.297297    0.181818  0.305091  0.145398  0.137521
# 1     0.000463   0.283784    0.298701  0.063415  0.021025  0.291121
# 2     0.006715   0.189189    0.402597  0.072294  0.017690  0.095762
# 3     0.010103   0.148649    0.558442  0.092355  0.017974  0.147493
# 4     0.012403   0.297297    0.610390  0.037838  0.003305  0.013887
# ..         ...        ...         ...       ...       ...       ...
# 211   0.941292   0.743243    0.389610  0.002053  0.010875  0.010492
# 212   0.968213   0.783784    0.168831  0.001663  0.011013  0.035554
# 213   0.980799   0.783784    0.402597  0.001747  0.006466  0.089542
# 214   0.993628   0.770270    0.571429  0.075684  0.003899  0.021033
# 215   1.000000   0.418919    0.480519  0.077746  0.049284  0.046062
#
#      HighAlpha   LowBeta  HighBeta  LowGamma  HighGamma  Key
# 0     0.352211  0.559510  0.338937  0.353816   0.279369    1
# ...

# %% [markdown]
# ### Correlaciones ###

# %%
experimento_4_normalizado.corr()
# Out:
#             Timestamp  Attention  Meditation     Delta     Theta  LowAlpha  \
# Timestamp    1.000000  -0.154775    0.320120 -0.209838 -0.165813 -0.180783
# Attention   -0.154775   1.000000   -0.337253 -0.394973 -0.297879 -0.379979
# Meditation   0.320120  -0.337253    1.000000 -0.038371 -0.098277  0.036288
# Delta       -0.209838  -0.394973   -0.038371  1.000000  0.508839  0.462371
# Theta       -0.165813  -0.297879   -0.098277  0.508839  1.000000  0.588160
# LowAlpha    -0.180783  -0.379979    0.036288  0.462371  0.588160  1.000000
# HighAlpha   -0.222596  -0.402225    0.040590  0.599507  0.629291  0.736949
# LowBeta     -0.269843  -0.332646   -0.179685  0.384711  0.427525  0.455164
# HighBeta    -0.000872   0.181032   -0.181765  0.129180  0.128546  0.147661
# LowGamma     0.100788   0.000589   -0.044503  0.238053  0.374320  0.251668
# HighGamma    0.089563  -0.129166    0.120066  0.172401  0.227247  0.171129
# ...

# %%
import seaborn as sns
sns.heatmap(experimento_4_normalizado.corr(), cmap="BrBG")
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))

sns.heatmap(experimento_4_normalizado.corr(), annot=True, cmap='coolwarm', fmt=".2f")

plt.title('Matriz de correlación')

plt.show()

# %%
matriz_correlacion = experimento_4_normalizado.corr()

# %%
correlation_matrix
# Out:
#             Timestamp  Attention  Meditation     Delta     Theta  LowAlpha  \
# Timestamp    1.000000  -0.154775    0.320120 -0.209838 -0.165813 -0.180783
# Attention   -0.154775   1.000000   -0.337253 -0.394973 -0.297879 -0.379979
# Meditation   0.320120  -0.337253    1.000000 -0.038371 -0.098277  0.036288
# Delta       -0.209838  -0.394973   -0.038371  1.000000  0.508839  0.462371
# Theta       -0.165813  -0.297879   -0.098277  0.508839  1.000000  0.588160
# LowAlpha    -0.180783  -0.379979    0.036288  0.462371  0.588160  1.000000
# HighAlpha   -0.222596  -0.402225    0.040590  0.599507  0.629291  0.736949
# LowBeta     -0.269843  -0.332646   -0.179685  0.384711  0.427525  0.455164
# HighBeta    -0.000872   0.181032   -0.181765  0.129180  0.128546  0.147661
# LowGamma     0.100788   0.000589   -0.044503  0.238053  0.374320  0.251668
# HighGamma    0.089563  -0.129166    0.120066  0.172401  0.227247  0.171129
# ...

# %%
sns.pairplot(matriz_correlacion, height=2.5)
plt.tight_layout()
plt.show()

# %%
sns.pairplot(
    matriz_correlacion, kind='reg', diag_kind='kde', plot_kws={'line_kws': {'color': 'red'}}
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Deep Learning ###

# %% [markdown]
# # clasificacion y generar features #

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

model = KNeighborsClassifier()

X = experimento_4_normalizado.drop('Key', axis=1)
y = experimento_4_normalizado['Key']

print (X)
print (y)
# Out:
#      Timestamp  Attention  Meditation     Delta     Theta  LowAlpha  \
# 0     0.000000   0.297297    0.181818  0.305091  0.145398  0.137521
# 1     0.000463   0.283784    0.298701  0.063415  0.021025  0.291121
# 2     0.006715   0.189189    0.402597  0.072294  0.017690  0.095762
# 3     0.010103   0.148649    0.558442  0.092355  0.017974  0.147493
# 4     0.012403   0.297297    0.610390  0.037838  0.003305  0.013887
# ..         ...        ...         ...       ...       ...       ...
# 211   0.941292   0.743243    0.389610  0.002053  0.010875  0.010492
# 212   0.968213   0.783784    0.168831  0.001663  0.011013  0.035554
# 213   0.980799   0.783784    0.402597  0.001747  0.006466  0.089542
# 214   0.993628   0.770270    0.571429  0.075684  0.003899  0.021033
# 215   1.000000   0.418919    0.480519  0.077746  0.049284  0.046062
#
#      HighAlpha   LowBeta  HighBeta  LowGamma  HighGamma
# 0     0.352211  0.559510  0.338937  0.353816   0.279369
# ...

# %%
# KNeighborsClassifier y accuracy_score

# Se dividen los datos. X_train sera el 80% de los datos
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0,
                                   train_size=0.6) # 0.8, el 80% de los datos para entrenamiento

# Entreno el modelo con el 80% de los datos
model.fit(X_train, y_train)

# Evalua el modelo con el 40% restante
y_predict = model.predict(X_test)
accuracy_score(y_test, y_predict)
# Out:
# 0.28735632183908044

# %%
# Atención a que por el momento estoy usando el mismo método pero con 0.5 de train_size
X1, X2, y1, y2 = train_test_split(X, y, random_state=0,
                                   train_size=0.5)


y2_model = model.fit(X1, y1).predict(X2)
y1_model = model.fit(X2, y2).predict(X1)
aciertos = accuracy_score(y1, y1_model), accuracy_score(y2, y2_model)

# tengo 2 modelos, tengo dos tasas de acierto y hago la media
print(aciertos)
print(np.array(aciertos).mean())
# Out:
# (0.26851851851851855, 0.3333333333333333)
# 0.30092592592592593

# %%
from sklearn.model_selection import cross_val_score

# model recordemos que sigue siendo el algoritmo de Vecinos más cercanos
scores = cross_val_score(model, X, y, cv=4)
scores.mean()
# Out:
# 0.17592592592592593

# %%
# mostrando el accuracy (tasa de acierto) medio y su desviación
# Usando formateo de texto
print("Acierto: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Sin usar formateo de texto
print("Acierto: ",scores.mean(), "(+/- ",scores.std() * 2,")")
# Out:
# Acierto: 0.18 (+/- 0.12)
# Acierto:  0.17592592592592593 (+/-  0.12422599874998831 )

# %%
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_predict
from sklearn import metrics

predicted = cross_val_predict(model, X, y, cv=5)


# obtención de la matriz de confusión
# filas -> reales
# columnas -> predicciones
cnf_matrix = confusion_matrix(y, predicted)
cnf_matrix
# Out:
# array([[19, 10, 13, 15,  5],
#        [11, 12,  7,  9,  3],
#        [16,  5,  1,  6,  4],
#        [18,  8,  8,  9,  4],
#        [18,  3,  5,  5,  2]], dtype=int64)

# %%
class_names = experimento_4_normalizado['Key'].unique()
conf_mat_df = pd.DataFrame(cnf_matrix, index=class_names, columns=class_names)
conf_mat_df
# Out:
#     1   0   3   4  2
# 1  19  10  13  15  5
# 0  11  12   7   9  3
# 3  16   5   1   6  4
# 4  18   8   8   9  4
# 2  18   3   5   5  2

# %%
# DecisionTreeClassifier y BaggingClassifier

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier

tree = DecisionTreeClassifier()

bag = BaggingClassifier(tree, n_estimators=100, max_samples=0.8,
                        random_state=1)
bag.fit(X, y)

# Evalua el modelo con el 40% restante
y_predict = model.predict(X_test)
accuracy_score(y_test, y_predict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[282], line 15
#      13 y_predict = model.predict(X_test)
#      14 accuracy_score(y_test, y_predict)
# ---> 15 cnf_matrix = confusion_matrix(y, y_predict)
#      16 cnf_matrix
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:317, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     232 def confusion_matrix(
#     233     y_true, y_pred, *, labels=None, sample_weight=None, normalize=None
#     234 ):
#     235     """Compute confusion matrix to evaluate the accuracy of a classification.
#     236
#     237     By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     315     (0, 2, 1, 1)
#     316     """
# --> 317     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     318     if y_type not in ("binary", "multiclass"):
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
