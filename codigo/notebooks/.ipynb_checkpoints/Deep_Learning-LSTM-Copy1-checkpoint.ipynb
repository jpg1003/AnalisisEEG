# %% [markdown]
# <img style="float:left" width="70%" src="../../documentacion/imagenes/escudo_COLOR_1L_DCHA.png">
# <img style="float:right" width="10%" src="../../documentacion/imagenes/PythonLogo.svg">
# <br style="clear:both;">
#
#
# <h2 style="display: inline-block; padding: 4mm; padding-left: 2em; background-color: navy; line-height: 1.3em; color: white; border-radius: 10px;">8.3. Deep Learning LSTM</h2>
#
#
#
# ## Estudiante:
#
# - Jose Luis Perez Gomez

# %%
# %run 3.Importaciones.ipynb
# %run 4.Variables_Clases.ipynb

# %%
datosEEG_seg1_standarizado = pd.read_csv('../datos/csv/seg1_stscaler.csv', sep=',')
datosEEG_seg2_standarizado = pd.read_csv('../datos/csv/seg2_stscaler.csv', sep=',')
datosEEG_seg3_standarizado = pd.read_csv('../datos/csv/seg3_stscaler.csv', sep=',')
datosEEG_seg4_standarizado = pd.read_csv('../datos/csv/seg4_stscaler.csv', sep=',')
nombre_clases = valores_key(datosEEG_seg1_standarizado)

# %%
# voy a dividir los datos en:

# Train: Segmento 3 y 4
# Validate: Segmento 2
# Test: Segmento 1

# %%
datosEEG_train = dataframes_sin_outliers_all = pd.concat([datosEEG_seg3_standarizado, datosEEG_seg4_standarizado], axis=0)
datosEEG_val = datosEEG_seg2_standarizado
datosEEG_test = datosEEG_seg1_standarizado

# %%
y_train = datosEEG_train['Key'].values
X_train = datosEEG_train.drop(columns=['Key']).values

y_val = datosEEG_val['Key'].values
X_val = datosEEG_val.drop(columns=['Key']).values

y_test = datosEEG_test['Key'].values
X_test = datosEEG_test.drop(columns=['Key']).values


X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_val = X_val.reshape((X_val.shape[0], 1, X_val.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# %% [markdown]
# # LSTM (Long short-term memory)

# %%
# Definir parámetros
timesteps = X_train.shape[1]
features = X_train.shape[2]
num_classes = len(np.unique(y_train))

model_lstm = Sequential([
    LSTM(units=20, input_shape=(timesteps, features), return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.3)),
    Dropout(0.3),
    LSTM(units=20, kernel_regularizer=tf.keras.regularizers.l2(0.3)),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])

model_lstm.compile(optimizer='adam', metrics=['accuracy'], loss='sparse_categorical_crossentropy')
# Out:
# C:\Users\Casa\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Definir callbacks
early_stopping = EarlyStopping(patience=10, restore_best_weights=True)
reduce_rl = ReduceLROnPlateau(patience=5)
model_checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True)

# %%
# Entrenar el modelo
model_lstm_trained = model_lstm.fit(X_train, y_train, epochs=20, batch_size=30, validation_data=(X_val, y_val), callbacks=[early_stopping, reduce_rl, model_checkpoint, plot_learning])

#model_lstm_trained = model_lstm.fit(X_train, y_train, epochs=50, batch_size=30, validation_data= (X_val, y_val), callbacks=[early_stopping, plot_learning, timer_callback, reduce_rl, model_checkpoint])
#model_lstm_trained = model_lstm.fit(X_train, y_train, epochs=30, batch_size=1, validation_data= (X_val, y_val), callbacks=[plot_learning])

y_pred = model_lstm.predict(X_test)

y_pred_classes = np.argmax(y_pred, axis=1)


accuracy_score_lstm = accuracy_score(y_test, y_pred_classes)
matriz_confusion_lstm = confusion_matrix(y_test, y_pred_classes)

total_simple_lstm_trained = model_lstm_trained
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2633 - loss: 2.3310 - val_accuracy: 0.2615 - val_loss: 2.2474 - learning_rate: 0.0010
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step

# %%
datos_lstm = pd.DataFrame(accuracy_score_lstm, columns=['LSTM'], index=['Experimento_X'])

display(datos_lstm)


# Crea el DataFrame de la matriz de confusión
mc_lstm = pd.DataFrame(matriz_confusion_lstm, index=nombre_clases, columns=nombre_clases)

# Configura la figura
fig, ax = plt.subplots(figsize=(8, 6))

# Crea la visualización de la matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=mc_lstm.values, display_labels=nombre_clases)
disp.plot(ax=ax, colorbar=True, cmap='Blues')

# Añade el título (usando el primer título de titulos_all)
ax.set_title(titulos_all[0])

# Ajusta el espaciado y muestra la gráfica
plt.tight_layout()
plt.show()
# Out:
#                    LSTM
# Experimento_X  0.245614

# %%
# Función para imprimir la gráfica
def print_chart(ax, titulo_grafica, x_eje, y_eje, datos_lineas, titulos_lineas):
    for linea in datos_lineas:
        ax.plot(linea)
    ax.set_title(titulo_grafica)
    ax.set_xlabel(x_eje)
    ax.set_ylabel(y_eje)
    ax.legend(titulos_lineas, loc='best')

# Crear una figura con dos subgráficos
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Imprimir la gráfica de precisión (accuracy) en el primer subgráfico
print_chart(axes[0], "Model Accuracy", "Epoch", "Accuracy", 
            [model_lstm_trained.history['accuracy'], model_lstm_trained.history['val_accuracy']], ['Train', 'Validation'])

# Imprimir la gráfica de pérdida (loss) en el segundo subgráfico
print_chart(axes[1], "Model Loss", "Epoch", "Loss", 
            [model_lstm_trained.history['loss'], model_lstm_trained.history['val_loss']], ['Train', 'Validation'])

# Ajustar el espaciado entre los subgráficos
plt.tight_layout()

# Mostrar las gráficas
plt.show()

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd


datosEEG_train = dataframes_sin_outliers_all = pd.concat([datosEEG_seg1_standarizado, datosEEG_seg2_standarizado], axis=0)
datosEEG_val = datosEEG_seg3_standarizado
datosEEG_test = datosEEG_seg4_standarizado



# Preparar los datos
X_train = datosEEG_train.drop(columns=['Key']).values
y_train = datosEEG_train['Key'].values

X_val = datosEEG_val.drop(columns=['Key']).values
y_val = datosEEG_val['Key'].values

X_test = datosEEG_test.drop(columns=['Key']).values
y_test = datosEEG_test['Key'].values

# Normalizar los datos
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# Redimensionar los datos
X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], 1, X_train_scaled.shape[1]))
X_val_scaled = X_val_scaled.reshape((X_val_scaled.shape[0], 1, X_val_scaled.shape[1]))
X_test_scaled = X_test_scaled.reshape((X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))

# Verificar el balance de clases
#print("Train class distribution:")
#print(pd.Series(y_train).value_counts())

#print("Validation class distribution:")
#print(pd.Series(y_val).value_counts())

#print("Test class distribution:")
#print(pd.Series(y_test).value_counts())

# Definir el modelo con menos unidades y más regularización
def build_model(timesteps, features, num_classes):
    model = Sequential([
        Input(shape=(timesteps, features)),  # Usar Input para definir la forma de entrada
        LSTM(units=120, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.02)),
        Dropout(0.3),
        LSTM(units=120, kernel_regularizer=tf.keras.regularizers.l2(0.02)),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', metrics=['accuracy'], loss='sparse_categorical_crossentropy')
    return model

# Definir parámetros
timesteps = X_train_scaled.shape[1]
features = X_train_scaled.shape[2]
num_classes = len(np.unique(y_train))

# Construir el modelo
model = build_model(timesteps, features, num_classes)

# Definir callbacks
early_stopping = EarlyStopping(patience=10, restore_best_weights=True)
reduce_rl = ReduceLROnPlateau(patience=5)
model_checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True)

# Entrenar el modelo
history = model.fit(X_train_scaled, y_train, epochs=200, batch_size=60, validation_data=(X_val_scaled, y_val), callbacks=[early_stopping, reduce_rl, model_checkpoint])

# Evaluar el modelo en los datos de prueba
y_pred = model.predict(X_test_scaled)
y_pred_classes = np.argmax(y_pred, axis=1)

# Calcular la precisión y la matriz de confusión
accuracy_score_lstm = accuracy_score(y_test, y_pred_classes)
matriz_confusion_lstm = confusion_matrix(y_test, y_pred_classes)

print(f'Accuracy: {accuracy_score_lstm}')
print(f'Confusion Matrix:\n{matriz_confusion_lstm}')

# Función para imprimir la gráfica
def print_chart(ax, titulo_grafica, x_eje, y_eje, datos_lineas, titulos_lineas):
    for linea in datos_lineas:
        ax.plot(linea)
    ax.set_title(titulo_grafica)
    ax.set_xlabel(x_eje)
    ax.set_ylabel(y_eje)
    ax.legend(titulos_lineas, loc='best')

# Crear una figura con dos subgráficos
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Imprimir la gráfica de precisión (accuracy) en el primer subgráfico
print_chart(axes[0], "Model Accuracy", "Epoch", "Accuracy", 
            [history.history['accuracy'], history.history['val_accuracy']], ['Train', 'Validation'])

# Imprimir la gráfica de pérdida (loss) en el segundo subgráfico
print_chart(axes[1], "Model Loss", "Epoch", "Loss", 
            [history.history['loss'], history.history['val_loss']], ['Train', 'Validation'])

# Ajustar el espaciado entre los subgráficos
plt.tight_layout()

# Mostrar las gráficas
plt.show()
# Out:
# Epoch 1/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.2306 - loss: 5.6976 - val_accuracy: 0.2353 - val_loss: 5.2285 - learning_rate: 0.0010
# Epoch 2/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2373 - loss: 5.1162 - val_accuracy: 0.2706 - val_loss: 4.6992 - learning_rate: 0.0010
# Epoch 3/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2535 - loss: 4.5991 - val_accuracy: 0.2529 - val_loss: 4.2318 - learning_rate: 0.0010
# Epoch 4/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2521 - loss: 4.1433 - val_accuracy: 0.2882 - val_loss: 3.8227 - learning_rate: 0.0010
# Epoch 5/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2846 - loss: 3.7447 - val_accuracy: 0.2765 - val_loss: 3.4678 - learning_rate: 0.0010
# Epoch 6/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2703 - loss: 3.4008 - val_accuracy: 0.2765 - val_loss: 3.1621 - learning_rate: 0.0010
# Epoch 7/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2268 - loss: 3.1039 - val_accuracy: 0.2882 - val_loss: 2.9007 - learning_rate: 0.0010
# Epoch 8/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2395 - loss: 2.8518 - val_accuracy: 0.2824 - val_loss: 2.6785 - learning_rate: 0.0010
# Epoch 9/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2750 - loss: 2.6355 - val_accuracy: 0.2471 - val_loss: 2.4909 - learning_rate: 0.0010
# Epoch 10/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3023 - loss: 2.4531 - val_accuracy: 0.2353 - val_loss: 2.3333 - learning_rate: 0.0010
# Epoch 11/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3078 - loss: 2.3008 - val_accuracy: 0.2824 - val_loss: 2.2011 - learning_rate: 0.0010
# Epoch 12/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3177 - loss: 2.1722 - val_accuracy: 0.2882 - val_loss: 2.0911 - learning_rate: 0.0010
# Epoch 13/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2707 - loss: 2.0676 - val_accuracy: 0.2529 - val_loss: 1.9997 - learning_rate: 0.0010
# Epoch 14/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2606 - loss: 1.9797 - val_accuracy: 0.2529 - val_loss: 1.9242 - learning_rate: 0.0010
# Epoch 15/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2574 - loss: 1.9053 - val_accuracy: 0.2529 - val_loss: 1.8622 - learning_rate: 0.0010
# Epoch 16/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2685 - loss: 1.8469 - val_accuracy: 0.2529 - val_loss: 1.8113 - learning_rate: 0.0010
# Epoch 17/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2400 - loss: 1.8003 - val_accuracy: 0.2529 - val_loss: 1.7696 - learning_rate: 0.0010
# Epoch 18/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2481 - loss: 1.7596 - val_accuracy: 0.2529 - val_loss: 1.7360 - learning_rate: 0.0010
# Epoch 19/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2428 - loss: 1.7274 - val_accuracy: 0.2529 - val_loss: 1.7090 - learning_rate: 0.0010
# Epoch 20/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2669 - loss: 1.7004 - val_accuracy: 0.2529 - val_loss: 1.6871 - learning_rate: 0.0010
# Epoch 21/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2646 - loss: 1.6790 - val_accuracy: 0.2529 - val_loss: 1.6695 - learning_rate: 0.0010
# Epoch 22/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2273 - loss: 1.6642 - val_accuracy: 0.2529 - val_loss: 1.6553 - learning_rate: 0.0010
# Epoch 23/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2366 - loss: 1.6511 - val_accuracy: 0.2529 - val_loss: 1.6440 - learning_rate: 0.0010
# Epoch 24/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2745 - loss: 1.6352 - val_accuracy: 0.2529 - val_loss: 1.6350 - learning_rate: 0.0010
# Epoch 25/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2803 - loss: 1.6273 - val_accuracy: 0.2529 - val_loss: 1.6281 - learning_rate: 0.0010
# Epoch 26/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2474 - loss: 1.6262 - val_accuracy: 0.2529 - val_loss: 1.6227 - learning_rate: 0.0010
# Epoch 27/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2516 - loss: 1.6189 - val_accuracy: 0.2529 - val_loss: 1.6183 - learning_rate: 0.0010
# Epoch 28/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2611 - loss: 1.6111 - val_accuracy: 0.2529 - val_loss: 1.6149 - learning_rate: 0.0010
# Epoch 29/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2493 - loss: 1.6116 - val_accuracy: 0.2529 - val_loss: 1.6123 - learning_rate: 0.0010
# Epoch 30/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2634 - loss: 1.6067 - val_accuracy: 0.2529 - val_loss: 1.6104 - learning_rate: 0.0010
# Epoch 31/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2423 - loss: 1.6096 - val_accuracy: 0.2529 - val_loss: 1.6088 - learning_rate: 0.0010
# Epoch 32/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2611 - loss: 1.6035 - val_accuracy: 0.2529 - val_loss: 1.6075 - learning_rate: 0.0010
# Epoch 33/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2324 - loss: 1.6086 - val_accuracy: 0.2529 - val_loss: 1.6069 - learning_rate: 0.0010
# Epoch 34/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2632 - loss: 1.6017 - val_accuracy: 0.2529 - val_loss: 1.6066 - learning_rate: 0.0010
# Epoch 35/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2449 - loss: 1.6047 - val_accuracy: 0.2529 - val_loss: 1.6063 - learning_rate: 0.0010
# Epoch 36/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2366 - loss: 1.6059 - val_accuracy: 0.2529 - val_loss: 1.6063 - learning_rate: 0.0010
# Epoch 37/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2458 - loss: 1.6026 - val_accuracy: 0.2529 - val_loss: 1.6063 - learning_rate: 0.0010
# Epoch 38/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2585 - loss: 1.6006 - val_accuracy: 0.2529 - val_loss: 1.6063 - learning_rate: 0.0010
# Epoch 39/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2456 - loss: 1.6035 - val_accuracy: 0.2529 - val_loss: 1.6062 - learning_rate: 0.0010
# Epoch 40/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2641 - loss: 1.5989 - val_accuracy: 0.2529 - val_loss: 1.6061 - learning_rate: 0.0010
# Epoch 41/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2491 - loss: 1.6021 - val_accuracy: 0.2529 - val_loss: 1.6061 - learning_rate: 0.0010
# Epoch 42/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2618 - loss: 1.5979 - val_accuracy: 0.2529 - val_loss: 1.6064 - learning_rate: 0.0010
# Epoch 43/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2599 - loss: 1.6003 - val_accuracy: 0.2529 - val_loss: 1.6066 - learning_rate: 0.0010
# Epoch 44/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2509 - loss: 1.6010 - val_accuracy: 0.2529 - val_loss: 1.6065 - learning_rate: 0.0010
# Epoch 45/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2541 - loss: 1.6024 - val_accuracy: 0.2529 - val_loss: 1.6066 - learning_rate: 1.0000e-04
# Epoch 46/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2794 - loss: 1.5949 - val_accuracy: 0.2529 - val_loss: 1.6066 - learning_rate: 1.0000e-04
# Epoch 47/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2507 - loss: 1.6019 - val_accuracy: 0.2529 - val_loss: 1.6065 - learning_rate: 1.0000e-04
# Epoch 48/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2525 - loss: 1.6008 - val_accuracy: 0.2529 - val_loss: 1.6065 - learning_rate: 1.0000e-04
# Epoch 49/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2699 - loss: 1.5982 - val_accuracy: 0.2529 - val_loss: 1.6065 - learning_rate: 1.0000e-04
# Epoch 50/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2741 - loss: 1.5939 - val_accuracy: 0.2529 - val_loss: 1.6065 - learning_rate: 1.0000e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Accuracy: 0.2802547770700637
# Confusion Matrix:
# [[44  0  0  0  0]
#  [33  0  0  0  0]
#  [25  0  0  0  0]
#  [26  0  0  0  0]
#  [29  0  0  0  0]]
