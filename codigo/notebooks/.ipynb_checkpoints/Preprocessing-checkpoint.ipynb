# %% [markdown]
# <img style="float:left" width="70%" src="../../documentacion/imagenes/escudo_COLOR_1L_DCHA.png">
# <img style="float:right" width="10%" src="../../documentacion/imagenes/PythonLogo.svg">
# <br style="clear:both;">
#
#
# <h2 style="display: inline-block; padding: 4mm; padding-left: 2em; background-color: navy; line-height: 1.3em; color: white; border-radius: 10px;">6. Preprocessing</h2>
#
#
#
# ## Estudiante:
#
# - Jose Luis Perez Gomez

# %%
# %run Importaciones.ipynb
# %run Variables_Clases.ipynb

# %%
display(HTML(html_h4('Realizo la importacion a un Dataframe de los datos del csv: ','blue')))
datosEEGTotal_csv = pd.read_csv('../datos/datosEEGTotal.csv', sep=';')
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h4><font color=blue>Realizo la importacion a un Dataframe de los datos del csv: </h4>
#
#     </body>
#     </html>

# %%
display(HTML(html_h4('Lo primero que voy a hacer es rellenar los datos missing de Key con la palabra Nothing  ', 'black')))
datosEEGTotal_csv_relleno = datosEEGTotal_csv.fillna("Nothing")
display(HTML(html_h5('Imprimo la info para revisar que no falte ningún dato, ahora no hay ningun dato missing', 'blue')))
datosEEGTotal_csv_relleno.info()
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h4><font color=black>Lo primero que voy a hacer es rellenar los datos missing de Key con la palabra Nothing  </h4>
#
#     </body>
#     </html>
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h5><font color=blue>Imprimo la info para revisar que no falte ningún dato, ahora no hay ningun dato missing</h5>
#
#     </body>
#     </html>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 726 entries, 0 to 725
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamp   726 non-null    int64
#  1   Attention   726 non-null    int64
#  2   Meditation  726 non-null    int64
#  3   Delta       726 non-null    int64
#  4   Theta       726 non-null    int64
#  5   LowAlpha    726 non-null    int64
#  6   HighAlpha   726 non-null    int64
#  7   LowBeta     726 non-null    int64
#  8   HighBeta    726 non-null    int64
#  9   LowGamma    726 non-null    int64
#  10  HighGamma   726 non-null    int64
#  11  Signal      726 non-null    int64
#  12  Key         726 non-null    object
# dtypes: int64(12), object(1)
# memory usage: 73.9+ KB

# %%
display(HTML(html_h4('Como se identifico en Carga de Datos, voy a modificar los datos de Key de LButton a Left  ', 'black')))

datosEEGTotal = datosEEGTotal_csv_relleno.replace({"LButton": 'Left'})

display(HTML(html_h5('Imprimo el grafico de barras para ver como estan de balanceados ahora los datos target', 'blue')))

# creo la figura 
fig = plt.figure(figsize = (15, 5))
 
# calculo la cantidad de datos de cada elemento en la columna Key
counts = datosEEGTotal['Key'].value_counts()

# creo el el barplot
plt.bar(counts.index, counts.values, color ='purple', width = 0.4)

# se muestra por cada dato el total de cada elemento
for i, count in enumerate(counts.values):
    plt.text(i, count, str(count), ha='center', va='bottom')

# etiquetas para el gráfico
plt.ylabel('Cantidad')
plt.title('Cantidad de elementos en la columna Key')

# Se muestra el gráfico
plt.show()

display(HTML(html_h5('Ahora ya se pueden orservar todos los datos y estan balanceados, Ya no aparece LButton que se ha integrado en Left y Nothing seria no ver o pulsar hacia ninguna direccion', 'blue')))
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h4><font color=black>Como se identifico en Carga de Datos, voy a modificar los datos de Key de LButton a Left  </h4>
#
#     </body>
#     </html>
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h5><font color=blue>Imprimo el grafico de barras para ver como estan de balanceados ahora los datos target</h5>
#
#     </body>
#     </html>
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h5><font color=blue>Ahora ya se pueden orservar todos los datos y estan balanceados, Ya no aparece LButton que se ha integrado en Left y Nothing seria no ver o pulsar hacia ninguna direccion</h5>
#
#     </body>
#     </html>

# %%
display(HTML(html_h4('Elimino columna Signal tal y como se observo en Carga de Datos  ', 'black')))

datosEEGTotal_sinsignal = datosEEGTotal.drop(['Signal'],axis=1)
display(datosEEGTotal_clean.columns)

display(HTML(html_h5('Se observa que ya no esta la caracteristica Signal', 'blue')))
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h4><font color=black>Elimino columna Signal tal y como se observo en Carga de Datos  </h4>
#
#     </body>
#     </html>
# Index(['Attention', 'Meditation', 'Delta', 'Theta', 'LowAlpha', 'HighAlpha',
#        'LowBeta', 'HighBeta', 'LowGamma', 'HighGamma'],
#       dtype='object')
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h5><font color=blue>Se observa que ya no esta la caracteristica Signal</h5>
#
#     </body>
#     </html>

# %%
display(HTML(html_h4('Voy a normalizar con MinMaX scaler los datos del conjunto de datos excepto de timestamp y de Key porque son datos que no deben modificarse para un correcto analisis  ', 'black')))

datosEEGTotal_clean = datosEEGTotal_sinsignal.drop(['Timestamp', 'Key'], axis=1)
datosEEGTotal_minmax = pd.DataFrame(MinMaxScaler().fit_transform(datosEEGTotal_clean), columns=datosEEGTotal_clean.columns)

print('Sin normalizar:')
display(datosEEGTotal_clean.head())
print('Normalizado:')
display(datosEEGTotal_minmax.head())


display(HTML(html_h5('El antes y despues de la normalizacion de los datos', 'blue')))
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h4><font color=black>Voy a normalizar con MinMaX scaler los datos del conjunto de datos excepto de timestamp y de Key porque son datos que no deben modificarse para un correcto analisis  </h4>
#
#     </body>
#     </html>
# Sin normalizar:
#    Attention  Meditation   Delta  Theta  LowAlpha  HighAlpha  LowBeta  \
# 0         84          48   25253  14225      3441       4172     1881
# 1         78          60    4946   5021      8879      13002      879
# 2         66          75  102896  14838     12817       8565     2890
# 3         61          87   57763  12541      6173       5120     3238
# 4         37          84   21560  74162     11297       9217     4844
#
#    HighBeta  LowGamma  HighGamma
# 0      9630      6863       5745
# 1      6367      4314       3150
# 2     14525      9144      23072
# 3     10192      9048       6663
# 4      1945      2644       1678
# Normalizado:
#    Attention  Meditation     Delta     Theta  LowAlpha  HighAlpha   LowBeta  \
# 0   0.838384    0.474747  0.009006  0.011185  0.006130   0.006843  0.001222
# 1   0.777778    0.595960  0.001631  0.003823  0.016003   0.021995  0.000523
# 2   0.656566    0.747475  0.037205  0.011676  0.023153   0.014381  0.001926
# 3   0.606061    0.868687  0.020813  0.009838  0.011090   0.008470  0.002168
# 4   0.363636    0.838384  0.007665  0.059127  0.020394   0.015500  0.003289
#
#    HighBeta  LowGamma  HighGamma
# 0  0.030424  0.039161   0.036669
# 1  0.019995  0.024421   0.019984
# 2  0.046070  0.052352   0.148078
# 3  0.032221  0.051796   0.042572
# 4  0.005862  0.014763   0.010519
#     <!DOCTYPE html>
#     <html>
#     <head>
#     </head>
#     <body>
#
#     <h5><font color=blue>El antes y despues de la normalizacion de los datos</h5>
#
#     </body>
#     </html>

# %%
exp_outliners = []

   
# Calculo el z-score para cada valor en el DataFrame
z_scores = stats.zscore(datosEEGTotal_minmax)

# Defino un umbral para los z-scores que considerará como outliers
# https://en.wikipedia.org/wiki/68%E2%80%9395%E2%80%9399.7_rule
umbral_zscore = 3

# Detecto los outliers basados en el z-score (valores cuyo valor absoluto de z-score es mayor que el umbral)
outliers = (abs(z_scores) > umbral_zscore)

# Cuento el número de outliers en cada columna
num_outliers_por_columna = outliers.sum(axis=0)

# Obtengo las filas y sus índices que son outliers en cada columna
outliers_por_columna = {}
for column in datosEEGTotal_minmax.columns:
    outliers_index = outliers[outliers[column]].index
    outliers_por_columna[column] = outliers_index

# Imprimir el número de outliers por cada columna
print("Número de outliers por columna:")
print(num_outliers_por_columna)

# Imprimir las filas con sus índices que son outliers en cada columna
#print("\nFilas con sus índices que son outliers por columna:")
#for column, indices in outliers_por_columna.items():
#    print(f"Columna '{column}': {list(zip(indices, datosEEGTotal_minmax.loc[indices][column]))}")

# Lista para almacenar todos los índices de outliers
todos_indices_outliers = []

# Almacenar todos los índices de outliers en una lista
for indices in outliers_por_columna.values():
    todos_indices_outliers.extend(indices)

# Convertir la lista de índices a un conjunto para eliminar duplicados
conjunto_indices_outliers = set(todos_indices_outliers)

# Lista ordenada de los índices únicos que no se repiten
indices_unicos_ordenados = sorted(list(conjunto_indices_outliers))

# Imprimir los índices únicos ordenados
print()
print("Índices únicos de outliers ordenados:")
print(f'Total: {len(indices_unicos_ordenados)}')
print(f'Lista: {indices_unicos_ordenados}')

# Construir un nuevo DataFrame que contenga las filas correspondientes a los índices únicos ordenados
dataframe_outliers = datosEEGTotal_minmax.loc[indices_unicos_ordenados]

# Imprimir el nuevo DataFrame de filas outliers únicas
#print("Nuevo DataFrame de filas outliers únicas:")
#display(dataframe_outliers)

# Agregar el DataFrame filtrado a la lista
exp_outliners.append(indices_unicos_ordenados)
# Out:
# Número de outliers por columna:
# Attention      0
# Meditation     0
# Delta         23
# Theta         11
# LowAlpha       8
# HighAlpha      8
# LowBeta        2
# HighBeta       6
# LowGamma       8
# HighGamma      6
# dtype: int64
#
# Índices únicos de outliers ordenados:
# Total: 42
# Lista: [9, 10, 23, 36, 48, 71, 72, 126, 142, 149, 169, 183, 202, 217, 227, 228, 242, 243, 247, 263, 268, 282, 283, 288, 303, 304, 313, 314, 354, 391, 414, 454, 474, 494, 515, 516, 518, 670, 678, 703, 715, 719]

# %%
# Iterar sobre los outliners y aplicar el proceso a cada uno de ellos
for out in exp_outliners:

    datosEEGTotal_nor = datosEEGTotal_minmax.drop(out)

    datosEEGTotal_nor_sinoutliners = datosEEGTotal_nor.reset_index(drop=True)


datosEEGTotal_nor_sinoutliners
# Out:
#      Attention  Meditation     Delta     Theta  LowAlpha  HighAlpha   LowBeta  \
# 0     0.838384    0.474747  0.009006  0.011185  0.006130   0.006843  0.001222
# 1     0.777778    0.595960  0.001631  0.003823  0.016003   0.021995  0.000523
# 2     0.656566    0.747475  0.037205  0.011676  0.023153   0.014381  0.001926
# 3     0.606061    0.868687  0.020813  0.009838  0.011090   0.008470  0.002168
# 4     0.363636    0.838384  0.007665  0.059127  0.020394   0.015500  0.003289
# ..         ...         ...       ...       ...       ...        ...       ...
# 679   0.808081    0.363636  0.001319  0.010831  0.001255   0.009184  0.004872
# 680   0.838384    0.191919  0.001102  0.010963  0.004056   0.003204  0.002222
# 681   0.838384    0.373737  0.001149  0.006626  0.010091   0.011121  0.003638
# 682   0.828283    0.505051  0.042317  0.004178  0.002433   0.010658  0.001503
# 683   0.565657    0.434343  0.043465  0.047467  0.005231   0.002402  0.003703
#
#      HighBeta  LowGamma  HighGamma
# 0    0.030424  0.039161   0.036669
# 1    0.019995  0.024421   0.019984
# 2    0.046070  0.052352   0.148078
# 3    0.032221  0.051796   0.042572
# 4    0.005862  0.014763   0.010519
# ..        ...       ...        ...
# 679  0.077088  0.074315   0.090139
# 680  0.072483  0.100915   0.063809
# 681  0.099851  0.131535   0.080443
# 682  0.022613  0.030417   0.007568
# 683  0.019493  0.017632   0.011844
#
# [684 rows x 10 columns]

# %%
#https://medium.com/@martacasdelg/c%C3%B3mo-identificar-y-tratar-outliers-con-python-bf7dd530fc3
#https://seaborn.pydata.org/generated/seaborn.boxplot.html


# Calcul0 el número de filas necesarias para mostrar dos boxplots por fila
num_cols = len(datosEEGTotal_nor_sinoutliners.columns)
num_rows = (num_cols) // 2

# Definir el tamaño de la figura
plt.figure(figsize=(12, 6))

# Iterar sobre cada columna del DataFrame filtrado
for i, column in enumerate(datosEEGTotal_nor_sinoutliners.columns):
    # Crear un subplot para cada columna
    plt.subplot(num_rows, 2, i + 1)
    
    # Trazar un boxplot para la columna actual
    sns.boxplot(data=datosEEGTotal_nor_sinoutliners, x=column)
    
    # Establecer el título del subplot como el nombre de la columna
    plt.title(column)

# Ajustar el diseño para evitar superposiciones
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ###  He elegido la normalizacion de los datos con MinMax para que el rango de los valores seas coherente. asi la comparacion sera mas acertada. valores similares y coherentes entre si

# %%
experimento_4_clean = pd.read_csv('../datos/experimento_4_clean.csv', sep=',')
experimento_3_clean = pd.read_csv('../datos/experimento_3_clean.csv', sep=',')
experimento_2_clean = pd.read_csv('../datos/experimento_2_clean.csv', sep=',')
experimento_1_clean = pd.read_csv('../datos/experimento_1_clean.csv', sep=',')


experimentos = [experimento_1_clean, experimento_2_clean, experimento_3_clean, experimento_4_clean]

# %%
display(experimento_4_clean)
# Out:
#      Timestamp  Attention  Meditation   Delta   Theta  LowAlpha  HighAlpha  \
# 0       123009         48          21  468675  174202      8577      19305
# 1       123120         47          30   98163   25886     18034      23444
# 2       124618         40          38  111774   21909      6006       1006
# 3       125430         37          50  142530   22248      9191       6086
# 4       125981         48          54   58951    4755       965       1237
# ..         ...        ...         ...     ...     ...       ...        ...
# 211     348567         81          37    4088   13782       756       5536
# 212     355018         84          20    3490   13947      2299       2051
# 213     358034         84          38    3619    8525      5623       6665
# 214     361108         83          51  116972    5464      1405       6395
# 215     362635         57          44  120133   59585      2946       1584
#
#      LowBeta  HighBeta  LowGamma  HighGamma  Key
# 0      17146     23426     29425      10122    4
# 1      10977     18521     15862      14097    0
# 2       6429      3344      7732       1616    0
# 3       5007      7385      5564       3634    0
# 4       3029      4567      3496        983    0
# ..       ...       ...       ...        ...  ...
# 211     7114     24230     12942      14061    2
# 212     3315     22789     17542       9966    2
# 213     5345     31352     22837      12553    2
# 214     2285      7186      5351       1219    2
# 215     5438      6210      3140       1884    0
#
# [216 rows x 12 columns]

# %%
# Lista que contendrá los DataFrames filtrados
exp_filtrados = []

# Iterar sobre los dataframes y aplicar la operación de filtrado a cada uno de ellos
for exp in experimentos:
    # Filtro el DataFrame para dejar fuera las columnas especificadas
    exp_filtrado = exp.drop(['Timestamp', 'Key'], axis=1)
    
    # Agregar el DataFrame filtrado a la lista
    exp_filtrados.append(exp_filtrado)

# %%
#https://medium.com/@martacasdelg/c%C3%B3mo-identificar-y-tratar-outliers-con-python-bf7dd530fc3
#https://seaborn.pydata.org/generated/seaborn.boxplot.html
    
# Filtro el DataFrame para dejar fuera las columnas especificadas
experimento_4_filtrado = experimento_4_clean.drop(['Timestamp', 'Key'], axis=1)

# Calcul0 el número de filas necesarias para mostrar dos boxplots por fila
num_cols = len(experimento_4_filtrado.columns)
num_rows = (num_cols) // 2

# Definir el tamaño de la figura
plt.figure(figsize=(12, 6))

# Iterar sobre cada columna del DataFrame filtrado
for i, column in enumerate(experimento_4_filtrado.columns):
    # Crear un subplot para cada columna
    plt.subplot(num_rows, 2, i + 1)
    
    # Trazar un boxplot para la columna actual
    sns.boxplot(data=experimento_4_filtrado, x=column)
    
    # Establecer el título del subplot como el nombre de la columna
    plt.title(column)

# Ajustar el diseño para evitar superposiciones
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
# Out:
# 1

# %%
display (experimento_4_minmax.head())
# Out:
#    Timestamp  Attention  Meditation     Delta     Theta  LowAlpha  HighAlpha  \
# 0     123009   0.212121    0.197183  0.909687  1.000000  0.421642   0.820364
# 1     123120   0.196970    0.323944  0.189085  0.144601  0.892585   1.000000
# 2     124618   0.090909    0.436620  0.215557  0.121664  0.293611   0.026171
# 3     125430   0.045455    0.605634  0.275374  0.123619  0.452219   0.246647
# 4     125981   0.212121    0.661972  0.112823  0.022729  0.042578   0.036196
#
#     LowBeta  HighBeta  LowGamma  HighGamma  Key
# 0  0.853637  0.399729  0.521073   0.394126    4
# 1  0.532201  0.302096  0.252200   0.565551    0
# 2  0.295227  0.000000  0.091032   0.027299    0
# 3  0.221134  0.080436  0.048053   0.114326    0
# 4  0.118070  0.024344  0.007057   0.000000    0

# %%
experimento_1_minmax.to_csv('../datos/experimento_1_nor.csv', index=False)
experimento_2_minmax.to_csv('../datos/experimento_2_nor.csv', index=False)
experimento_3_minmax.to_csv('../datos/experimento_3_nor.csv', index=False)
experimento_4_minmax.to_csv('../datos/experimento_4_nor.csv', index=False)
experimento_all_minmax = pd.concat([experimento_1_minmax, experimento_2_minmax, experimento_3_minmax, experimento_4_minmax])

# Guardar el resultado en un archivo CSV
experimento_all_minmax.to_csv('../datos/experimento_all_nor.csv', index=False) 

print()
print(color.BOLD +  color.UNDERLINE + color.RED + "Exporto todos los experimentos a un csv para tratarlo despues" + color.END )
print()
print(color.BOLD +  color.UNDERLINE + color.RED + "Exporto todos los experimentos a varios csv para tratarlos despues" + color.END )
print()
# Out:
# Exporto todos los experimentos a un csv para tratarlo despues
#
# Exporto todos los experimentos a varios csv para tratarlos despues

# %% [markdown]
# ### Correlaciones ###

# %%
experimento_1_minmax.corr()
# Out:
#             Timestamp  Attention  Meditation     Delta     Theta  LowAlpha  \
# Timestamp    1.000000  -0.396312    0.257554  0.047377 -0.016440  0.014142
# Attention   -0.396312   1.000000   -0.301875 -0.093399 -0.188227 -0.189731
# Meditation   0.257554  -0.301875    1.000000 -0.003696 -0.036430  0.021610
# Delta        0.047377  -0.093399   -0.003696  1.000000  0.610057  0.475226
# Theta       -0.016440  -0.188227   -0.036430  0.610057  1.000000  0.658636
# LowAlpha     0.014142  -0.189731    0.021610  0.475226  0.658636  1.000000
# HighAlpha   -0.001029  -0.116186    0.035101  0.410283  0.286405  0.545237
# LowBeta      0.031989  -0.063625   -0.179950  0.287155  0.447481  0.584649
# HighBeta    -0.259563   0.340478   -0.297378  0.083026  0.220511  0.359691
# LowGamma    -0.224510   0.126679   -0.066128 -0.154588  0.031279  0.144221
# HighGamma   -0.156138   0.225351   -0.170612 -0.125435  0.115851  0.138462
# Key          0.052689   0.054630    0.413242 -0.330086 -0.302241 -0.204070
#
#             HighAlpha   LowBeta  HighBeta  LowGamma  HighGamma       Key
# Timestamp   -0.001029  0.031989 -0.259563 -0.224510  -0.156138  0.052689
# Attention   -0.116186 -0.063625  0.340478  0.126679   0.225351  0.054630
# Meditation   0.035101 -0.179950 -0.297378 -0.066128  -0.170612  0.413242
# Delta        0.410283  0.287155  0.083026 -0.154588  -0.125435 -0.330086
# Theta        0.286405  0.447481  0.220511  0.031279   0.115851 -0.302241
# LowAlpha     0.545237  0.584649  0.359691  0.144221   0.138462 -0.204070
# HighAlpha    1.000000  0.264402  0.166738  0.114276   0.096735 -0.152785
# LowBeta      0.264402  1.000000  0.343194  0.201235   0.300921 -0.211738
# HighBeta     0.166738  0.343194  1.000000  0.458115   0.527482 -0.181757
# LowGamma     0.114276  0.201235  0.458115  1.000000   0.573907 -0.024535
# HighGamma    0.096735  0.300921  0.527482  0.573907   1.000000 -0.061285
# Key         -0.152785 -0.211738 -0.181757 -0.024535  -0.061285  1.000000

# %%
import seaborn as sns
sns.heatmap(experimento_1_minmax.corr(), cmap="BrBG")
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))

sns.heatmap(experimento_1_minmax.corr(),cmap='coolwarm')

plt.title('Matriz de correlación')

plt.show()

# %%
matriz_correlacion = experimento_1_minmax.corr()

# %%
matriz_correlacion
# Out:
#             Timestamp  Attention  Meditation     Delta     Theta  LowAlpha  \
# Timestamp    1.000000  -0.396312    0.257554  0.047377 -0.016440  0.014142
# Attention   -0.396312   1.000000   -0.301875 -0.093399 -0.188227 -0.189731
# Meditation   0.257554  -0.301875    1.000000 -0.003696 -0.036430  0.021610
# Delta        0.047377  -0.093399   -0.003696  1.000000  0.610057  0.475226
# Theta       -0.016440  -0.188227   -0.036430  0.610057  1.000000  0.658636
# LowAlpha     0.014142  -0.189731    0.021610  0.475226  0.658636  1.000000
# HighAlpha   -0.001029  -0.116186    0.035101  0.410283  0.286405  0.545237
# LowBeta      0.031989  -0.063625   -0.179950  0.287155  0.447481  0.584649
# HighBeta    -0.259563   0.340478   -0.297378  0.083026  0.220511  0.359691
# LowGamma    -0.224510   0.126679   -0.066128 -0.154588  0.031279  0.144221
# HighGamma   -0.156138   0.225351   -0.170612 -0.125435  0.115851  0.138462
# Key          0.052689   0.054630    0.413242 -0.330086 -0.302241 -0.204070
#
#             HighAlpha   LowBeta  HighBeta  LowGamma  HighGamma       Key
# Timestamp   -0.001029  0.031989 -0.259563 -0.224510  -0.156138  0.052689
# Attention   -0.116186 -0.063625  0.340478  0.126679   0.225351  0.054630
# Meditation   0.035101 -0.179950 -0.297378 -0.066128  -0.170612  0.413242
# Delta        0.410283  0.287155  0.083026 -0.154588  -0.125435 -0.330086
# Theta        0.286405  0.447481  0.220511  0.031279   0.115851 -0.302241
# LowAlpha     0.545237  0.584649  0.359691  0.144221   0.138462 -0.204070
# HighAlpha    1.000000  0.264402  0.166738  0.114276   0.096735 -0.152785
# LowBeta      0.264402  1.000000  0.343194  0.201235   0.300921 -0.211738
# HighBeta     0.166738  0.343194  1.000000  0.458115   0.527482 -0.181757
# LowGamma     0.114276  0.201235  0.458115  1.000000   0.573907 -0.024535
# HighGamma    0.096735  0.300921  0.527482  0.573907   1.000000 -0.061285
# Key         -0.152785 -0.211738 -0.181757 -0.024535  -0.061285  1.000000

# %%
matriz_correlacion = experimento_1_minmax.corr().abs()
suma_correlaciones = matriz_correlacion.sum()

componentes_principales = suma_correlaciones.nlargest(5).index
componentes_peores = suma_correlaciones.nsmallest(5).index

print("Las dos columnas seleccionadas para PCA son:", componentes_principales)
print("Las dos columnas seleccionadas con la peor correlación son:", componentes_peores)
# Out:
# Las dos columnas seleccionadas para PCA son: Index(['LowAlpha', 'HighBeta', 'LowBeta', 'Theta', 'Delta'], dtype='object')
# Las dos columnas seleccionadas con la peor correlación son: Index(['Timestamp', 'Meditation', 'Key', 'Attention', 'LowGamma'], dtype='object')

# %%
matriz_correlacion = experimento_2_minmax.corr().abs()
suma_correlaciones = matriz_correlacion.sum()

componentes_principales = suma_correlaciones.nlargest(5).index
componentes_peores = suma_correlaciones.nsmallest(5).index

print("Las dos columnas seleccionadas para PCA son:", componentes_principales)
print("Las dos columnas seleccionadas con la peor correlación son:", componentes_peores)
# Out:
# Las dos columnas seleccionadas para PCA son: Index(['Theta', 'LowAlpha', 'HighAlpha', 'LowBeta', 'Delta'], dtype='object')
# Las dos columnas seleccionadas con la peor correlación son: Index(['Timestamp', 'Meditation', 'Key', 'Attention', 'HighGamma'], dtype='object')

# %%
matriz_correlacion = experimento_3_minmax.corr().abs()
suma_correlaciones = matriz_correlacion.sum()

componentes_principales = suma_correlaciones.nlargest(5).index
componentes_peores = suma_correlaciones.nsmallest(5).index

print("Las dos columnas seleccionadas para PCA son:", componentes_principales)
print("Las dos columnas seleccionadas con la peor correlación son:", componentes_peores)
# Out:
# Las dos columnas seleccionadas para PCA son: Index(['LowAlpha', 'HighBeta', 'LowBeta', 'Theta', 'LowGamma'], dtype='object')
# Las dos columnas seleccionadas con la peor correlación son: Index(['Timestamp', 'Meditation', 'Key', 'Attention', 'HighGamma'], dtype='object')

# %%
matriz_correlacion = experimento_4_minmax.corr().abs()
suma_correlaciones = matriz_correlacion.sum()

componentes_principales = suma_correlaciones.nlargest(5).index
componentes_peores = suma_correlaciones.nsmallest(5).index

print("Las dos columnas seleccionadas para PCA son:", componentes_principales)
print("Las dos columnas seleccionadas con la peor correlación son:", componentes_peores)
# Out:
# Las dos columnas seleccionadas para PCA son: Index(['Attention', 'Theta', 'HighAlpha', 'Delta', 'LowBeta'], dtype='object')
# Las dos columnas seleccionadas con la peor correlación son: Index(['Key', 'HighGamma', 'LowGamma', 'HighBeta', 'Timestamp'], dtype='object')

# %%
matriz_correlacion = experimento_all_minmax.corr().abs()
suma_correlaciones = matriz_correlacion.sum()

componentes_principales = suma_correlaciones.nlargest(5).index
componentes_peores = suma_correlaciones.nsmallest(5).index

print("Las dos columnas seleccionadas para PCA son:", componentes_principales)
print("Las dos columnas seleccionadas con la peor correlación son:", componentes_peores)
# Out:
# Las dos columnas seleccionadas para PCA son: Index(['LowBeta', 'LowAlpha', 'HighAlpha', 'HighBeta', 'Theta'], dtype='object')
# Las dos columnas seleccionadas con la peor correlación son: Index(['Meditation', 'Key', 'Timestamp', 'Attention', 'HighGamma'], dtype='object')

# %%
experimento_all_minmax_1 = experimento_all_minmax.drop(['Timestamp', 'Meditation', 'Attention','LowGamma', 'HighGamma'], axis=1)

# %%
experimento_all_minmax_1.head()
# Out:
#       Delta     Theta  LowAlpha  HighAlpha   LowBeta  HighBeta  Key
# 0  0.021185  0.079462  0.061727   0.076266  0.100597  0.548819    4
# 1  0.003739  0.027162  0.164694   0.255753  0.034888  0.340997    0
# 2  0.049114  0.069893  0.113457   0.095536  0.189586  0.584612    0
# 3  0.018012  0.420046  0.210478   0.178815  0.294905  0.059359    0
# 4  0.001672  0.006495  0.009676   0.000955  0.063348  0.080122    0

# %%
matriz_correlacion = experimento_all_minmax_1.corr().abs()
suma_correlaciones = matriz_correlacion.sum()

componentes_principales = suma_correlaciones.nlargest(4).index
componentes_peores = suma_correlaciones.nsmallest(4).index

print("Las dos columnas seleccionadas para PCA son:", componentes_principales)
print("Las dos columnas seleccionadas con la peor correlación son:", componentes_peores)
# Out:
# Las dos columnas seleccionadas para PCA son: Index(['LowAlpha', 'Theta', 'HighAlpha', 'LowBeta'], dtype='object')
# Las dos columnas seleccionadas con la peor correlación son: Index(['Key', 'HighBeta', 'Delta', 'LowBeta'], dtype='object')

# %%
'''
sns.pairplot(matriz_correlacion, height=2.5)
plt.tight_layout()
plt.show()
'''
# Out:
# '\nsns.pairplot(matriz_correlacion, height=2.5)\nplt.tight_layout()\nplt.show()\n'

# %%
'''
sns.pairplot(
    matriz_correlacion, kind='reg', diag_kind='kde', plot_kws={'line_kws': {'color': 'red'}}
)
plt.tight_layout()
plt.show()

'''
# Out:
# "\nsns.pairplot(\n    matriz_correlacion, kind='reg', diag_kind='kde', plot_kws={'line_kws': {'color': 'red'}}\n)\nplt.tight_layout()\nplt.show()\n\n"

# %%
experimento_4_minmax
# Out:
#      Timestamp  Attention  Meditation     Delta     Theta  LowAlpha  \
# 0       123009   0.212121    0.197183  0.909687  1.000000  0.421642
# 1       123120   0.196970    0.323944  0.189085  0.144601  0.892585
# 2       124618   0.090909    0.436620  0.215557  0.121664  0.293611
# 3       125430   0.045455    0.605634  0.275374  0.123619  0.452219
# 4       125981   0.212121    0.661972  0.112823  0.022729  0.042578
# ..         ...        ...         ...       ...       ...       ...
# 193     348567   0.712121    0.422535  0.006121  0.074792  0.032170
# 194     355018   0.757576    0.183099  0.004958  0.075743  0.109009
# 195     358034   0.757576    0.436620  0.005208  0.044473  0.274538
# 196     361108   0.742424    0.619718  0.225667  0.026818  0.064489
# 197     362635   0.348485    0.521127  0.231814  0.338957  0.141228
#
#      HighAlpha   LowBeta  HighBeta  LowGamma  HighGamma  Key
# 0     0.820364  0.853637  0.399729  0.521073   0.394126    4
# 1     1.000000  0.532201  0.302096  0.252200   0.565551    0
# 2     0.026171  0.295227  0.000000  0.091032   0.027299    0
# 3     0.246647  0.221134  0.080436  0.048053   0.114326    0
# 4     0.036196  0.118070  0.024344  0.007057   0.000000    0
# ..         ...       ...       ...       ...        ...  ...
# 193   0.222777  0.330919  0.415733  0.194314   0.563999    2
# 194   0.071525  0.132972  0.387050  0.285505   0.387399    2
# 195   0.271776  0.238745  0.557495  0.390473   0.498965    2
# 196   0.260058  0.079304  0.076474  0.043831   0.010178    2
# 197   0.051256  0.243591  0.057047  0.000000   0.038856    0
#
# [198 rows x 12 columns]

# %%
# sacar los 4 por pantalla

data = experimento_1_minmax
# creating the dataset

#y = dataframe['Key'].values
#X = dataframe.drop(columns=['Key']).values

labels1 = {'Left': "04", 'Right': "02" ,'Up': "01", 'Down': "03",'Nothing': "00"}

#labels = set(data['Key'].values)
values = data['Key'].values

labels = data['Key']. replace(labels1)

  
fig = plt.figure(figsize = (10, 5))
 
# Calcular la cantidad de cada elemento en la columna Key
counts = data['Key'].value_counts()

# Crear el barplot
plt.bar(counts.index, counts.values, color ='maroon', width = 0.4)

# Añadir etiquetas
plt.xlabel('Elemento')
plt.ylabel('Cantidad')
plt.title('Cantidad de elementos en la columna Key')

# Mostrar el gráfico
plt.show()
