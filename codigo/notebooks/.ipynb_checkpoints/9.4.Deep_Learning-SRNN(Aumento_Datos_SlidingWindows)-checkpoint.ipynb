# %% [markdown]
# <img style="float:left" width="70%" src="../../documentacion/imagenes/escudo_COLOR_1L_DCHA.png">
# <img style="float:right" width="10%" src="../../documentacion/imagenes/PythonLogo.svg">
# <br style="clear:both;">
#
#
# <h2 style="display: inline-block; padding: 4mm; padding-left: 2em; background-color: navy; line-height: 1.3em; color: white; border-radius: 10px;">9.4.Deep_Learning-SRNN(Aumento_Datos_SlidingWindows)</h2>
#
#
#
# ## Estudiante:
#
# - Jose Luis Perez Gomez

# %%
# %run 3.Importaciones.ipynb
# %run 4.Variables_Clases.ipynb

# %%
datosEEG_seg1_standarizado = pd.read_csv('../datos/csv/seg1_stscaler.csv', sep=',')
datosEEG_std_after_resampled = pd.read_csv('../datos/csv/datosEEG_std_after_resampled.csv', sep=',')
datosEEG_std_before_resampled = pd.read_csv('../datos/csv/datosEEG_std_before_resampled.csv', sep=',')
datosEEG_std_tres_segmentos = pd.read_csv('../datos/csv/datosEEG_std_tres_segmentos.csv', sep=',')

datosEEG_all = [datosEEG_std_after_resampled, datosEEG_std_before_resampled]

nombre_clases = valores_key(datosEEG_seg1_standarizado)

# %% [markdown]
# # Simple RNN (Simple Recurrent Neural Networks)

# %%
model_srnn_rs_sw = crear_modelo_LSTM(TIMESTEPS, FEATURES, NUM_CLASES)
# Out:
# C:\Users\Casa\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
accuracy_score_srnn_rs_sw = []
accuracy_score_test_srnn_rs_sw =[]
matriz_confusion_srnn_rs_sw = []
matriz_confusion_test_srnn_rs_sw = []
total_simple_srnn_rs_sw_trained = []

for dataset in datosEEG_all:   
       
    train_datos, val_datos, test_datos = dividir_datos_deep(dataset, TARGET)
    
    columns = train_datos.columns[train_datos.columns != TARGET]
    
    X_train, y_train = preparar_ventanas(train_datos[columns], train_datos[TARGET], WINDOWS_SIZE, OVERLAP )
    X_val, y_val = preparar_ventanas(val_datos[columns], val_datos[TARGET], WINDOWS_SIZE, OVERLAP )
    X_test, y_test = preparar_ventanas(test_datos[columns], test_datos[TARGET], WINDOWS_SIZE, OVERLAP )
            
    # Entrenar el modelo
    model_srnn_trained_rs_sw = model_srnn_rs_sw.fit(X_train, y_train, epochs=100, batch_size=30, validation_data= (X_val, y_val), callbacks=[early_stopping, REDUCE_RL, model_checkpoint, plot_learning])
    
    y_pred = model_srnn_rs_sw.predict(X_val)
    y_pred_classes = np.argmax(y_pred, axis=1)
    
    y_pred_test = model_srnn_rs_sw.predict(X_test)
    y_pred_classes_test = np.argmax(y_pred_test, axis=1)

    accuracy_score_srnn_rs_sw.append(accuracy_score(y_val, y_pred_classes))
    matriz_confusion_srnn_rs_sw.append(confusion_matrix(y_val, y_pred_classes))
    
    accuracy_score_test_srnn_rs_sw.append(accuracy_score(y_test, y_pred_classes_test))
    matriz_confusion_test_srnn_rs_sw.append(confusion_matrix(y_test, y_pred_classes_test))
    
    total_simple_srnn_rs_sw_trained.append(model_srnn_trained_rs_sw)
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.5088 - loss: 1.4253 - val_accuracy: 0.4596 - val_loss: 1.4266 - learning_rate: 1.0000e-04
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step

# %%
train_datos, val_datoS =  dividir_datos_deep_sr_wd(datosEEG_std_tres_segmentos, TARGET)
test_datos = datosEEG_seg1_standarizado

X_train, y_train = preparar_ventanas(train_datos[columns], train_datos[TARGET], WINDOWS_SIZE, OVERLAP )
X_val, y_val = preparar_ventanas(val_datos[columns], val_datos[TARGET], WINDOWS_SIZE, OVERLAP )
X_test, y_test = preparar_ventanas(test_datos[columns], test_datos[TARGET], WINDOWS_SIZE, OVERLAP )

# Entrenar el modelo
model_srnn_rs_sw_trained1 = model_srnn_rs_sw.fit(X_train, y_train, epochs=100, batch_size=30, validation_data= (X_val, y_val), callbacks=[early_stopping, REDUCE_RL, model_checkpoint, plot_learning])

y_pred = model_srnn_rs_sw.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)

y_pred_test = model_srnn_rs_sw.predict(X_test)
y_pred_classes_test = np.argmax(y_pred_test, axis=1)

accuracy_score_srnn_rs_sw.append(accuracy_score(y_val, y_pred_classes))
matriz_confusion_srnn_rs_sw.append(confusion_matrix(y_val, y_pred_classes))

accuracy_score_test_srnn_rs_sw.append(accuracy_score(y_test, y_pred_classes_test))
matriz_confusion_test_srnn_rs_sw.append(confusion_matrix(y_test, y_pred_classes_test))

#simple_rnn_loss, simple_rnn_accuracy = model_srnn.evaluate(X_test, y_test)
total_simple_srnn_rs_sw_trained.append(model_srnn_rs_sw_trained1)
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7050 - loss: 0.7974 - val_accuracy: 0.4064 - val_loss: 1.8316 - learning_rate: 1.0000e-04
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
datos_srnn_rs_sw = pd.DataFrame(accuracy_score_srnn_rs_sw, columns=['SRNN_RS_SW_VAL'], index=(titulos_all_rs))

display(datos_srnn_rs_sw)

mc_srnn = []

for matrices_srnn in matriz_confusion_srnn_rs_sw:

    mc_srnn.append(pd.DataFrame(matrices_srnn, index=nombre_clases, columns=nombre_clases))

#https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html

# Creo una figura y ejes para dividir el espacio en cuatro subgráficos
fig, axs = plt.subplots(1, 3, figsize=(10, 12))

# Matrices de confusión y títulos para cada subgráfico
dataframes = [mc_srnn[0], mc_srnn[1], mc_srnn[2]]


# Itero sobre los DataFrames y títulos para imprimir matriz de confusión en un subgráfico
for i, (dataframe, titulo) in enumerate(zip(dataframes, titulos_all_rs)):

    ax = axs[i]
   
    # Se crea la impresion de la matriz de confusión y se implime
    disp = ConfusionMatrixDisplay(confusion_matrix=dataframe.values, display_labels=(nombre_clases))
    disp.plot(ax=ax, colorbar=False, cmap='Blues')
    
    # Añado el título al subgráfico
    ax.set_title(titulo)

# Se ajusta el espaciado entre subgráficos
plt.tight_layout()

# Se imprime el gráfico
plt.show()
# Out:
#                       SRNN_RS_SW_VAL
# All Segmentos after         0.725532
# All Segmentos before        0.417021
# Test Datos Reales           0.404255

# %%
datos_srnn_rs_test_sw = pd.DataFrame(accuracy_score_test_srnn_rs_sw, columns=['SRNN_RS_SW_TEST'], index=(titulos_all_rs))

display(datos_srnn_rs_test_sw)

mc_srnn = []

for matrices_srnn in matriz_confusion_test_srnn_rs_sw:

    mc_srnn.append(pd.DataFrame(matrices_srnn, index=nombre_clases, columns=nombre_clases))

#https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html

# Creo una figura y ejes para dividir el espacio en cuatro subgráficos
fig, axs = plt.subplots(1, 3, figsize=(10, 12))

# Matrices de confusión y títulos para cada subgráfico
dataframes = [mc_srnn[0], mc_srnn[1], mc_srnn[2]]


# Itero sobre los DataFrames y títulos para imprimir matriz de confusión en un subgráfico
for i, (dataframe, titulo) in enumerate(zip(dataframes, titulos_all)):

    ax = axs[i]
   
    # Se crea la impresion de la matriz de confusión y se implime
    disp = ConfusionMatrixDisplay(confusion_matrix=dataframe.values, display_labels=(nombre_clases))
    disp.plot(ax=ax, colorbar=False, cmap='Blues')
    
    # Añado el título al subgráfico
    ax.set_title(titulo)

# Se ajusta el espaciado entre subgráficos
plt.tight_layout()

# Se imprime el gráfico
plt.show()
# Out:
#                       SRNN_RS_SW_TEST
# All Segmentos after          0.818182
# All Segmentos before         0.581818
# Test Datos Reales            0.675000

# %%
datos_srnn_rs_test_sw.to_csv(f'../datos/csv/datosEGG_SRNN_RS_SW_test.csv', index=False)
datos_srnn_rs_sw.to_csv(f'../datos/csv/datosEGG_SRNN_RS_SW_val.csv', index=False)
